# %%
import pandas as pd
import numpy as np
import pickle
from openpyxl import Workbook,load_workbook

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
from scipy.stats import skew,kurtosis
from advanced_analysis_package import analyze,variable_treatment,variable_reduction

# %%
import os

# %%
os.chdir('../pickles')

# %%
numerical=pickle.load(open('numerical.pickle','rb'))
categorical = pickle.load(open('categorical.pickle','rb'))

# %%
os.chdir('../output_data')

# %%
df = pd.read_csv('train_v03.csv',header=0)

# %%
for col in df.columns:
    if len(df[col].value_counts()) <= 1:
        df.drop(col,axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Prev_Close(in 10^5)', 'High_1d(in 10^5)', 'Low_1d(in 10^5)',
#        'Last_1d(in 10^5)', 'Close', 'VWAP_1d(in 10^5)', 'Volume_1d(in 10^9)',
#        'Turnover_1d(in 10^11)', 'Trades_1d(in 10^7)',
#        'Deliverable_Volume_1d(in 10^9)',
#        ...
#        'return_2d_500_sqr', 'return_3d_500_sqr', 'return_4d_500_sqr',
#        'return_5d_500_sqr', 'Voltality_500_log', 'Voltality_log',
#        'Sector_dum_0', 'Sector_dum_1', 'Sector_dum_2', 'Sector_dum_3'],
#       dtype='object', length=212)

# %%
edd_df =analyze.edd(df,dv='Close')

# %%
edd_df
# Out:
#                                 Var     type  count  nmiss  missing_rate  \
# 0               Prev_Close(in 10^5)  numeric  85799      0           0.0
# 1                  High_1d(in 10^5)  numeric  85799      0           0.0
# 2                   Low_1d(in 10^5)  numeric  85799      0           0.0
# 3                  Last_1d(in 10^5)  numeric  85799      0           0.0
# 4                             Close  numeric  85799      0           0.0
# 5                  VWAP_1d(in 10^5)  numeric  85799      0           0.0
# 6                Volume_1d(in 10^9)  numeric  85799      0           0.0
# 7             Turnover_1d(in 10^11)  numeric  85799      0           0.0
# 8                Trades_1d(in 10^7)  numeric  85799      0           0.0
# 9    Deliverable_Volume_1d(in 10^9)  numeric  85799      0           0.0
# 10                pct_Deliverble_1d  numeric  85799      0           0.0
# 11           Open_nifty_1d(in 10^5)  numeric  85799      0           0.0
# 12           High_nifty_1d(in 10^5)  numeric  85799      0           0.0
# 13            Low_nifty_1d(in 10^5)  numeric  85799      0           0.0
# 14          Close_nifty_1d(in 10^5)  numeric  85799      0           0.0
# 15         Volume_nifty_1d(in 10^9)  numeric  85799      0           0.0
# 16      Turnover_nifty_1d(in 10^11)  numeric  85799      0           0.0
# 17            Open_auto_1d(in 10^5)  numeric  85799      0           0.0
# 18            High_auto_1d(in 10^5)  numeric  85799      0           0.0
# 19             Low_auto_1d(in 10^5)  numeric  85799      0           0.0
# 20           Close_auto_1d(in 10^5)  numeric  85799      0           0.0
# 21            Open_bank_1d(in 10^5)  numeric  85799      0           0.0
# 22            High_bank_1d(in 10^5)  numeric  85799      0           0.0
# 23             Low_bank_1d(in 10^5)  numeric  85799      0           0.0
# 24           Close_bank_1d(in 10^5)  numeric  85799      0           0.0
# 25            Open_fmcg_1d(in 10^5)  numeric  85799      0           0.0
# 26            High_fmcg_1d(in 10^5)  numeric  85799      0           0.0
# 27             Low_fmcg_1d(in 10^5)  numeric  85799      0           0.0
# 28           Close_fmcg_1d(in 10^5)  numeric  85799      0           0.0
# 29              Open_it_1d(in 10^5)  numeric  85799      0           0.0
# ..                              ...      ...    ...    ...           ...
# 182                return_2d_it_sqr  numeric  85799      0           0.0
# 183               return_2d_it_cube  numeric  85799      0           0.0
# 184                return_3d_it_sqr  numeric  85799      0           0.0
# 185                return_4d_it_sqr  numeric  85799      0           0.0
# 186                return_5d_it_sqr  numeric  85799      0           0.0
# 187             Voltality_media_log  numeric  85799      0           0.0
# 188            Voltality_pharma_log  numeric  85799      0           0.0
# 189            return_1d_realty_sqr  numeric  85799      0           0.0
# 190           return_1d_realty_cube  numeric  85799      0           0.0
# 191            return_2d_realty_sqr  numeric  85799      0           0.0
# 192           return_2d_realty_cube  numeric  85799      0           0.0
# 193            return_3d_realty_sqr  numeric  85799      0           0.0
# 194           return_3d_realty_cube  numeric  85799      0           0.0
# 195            return_4d_realty_sqr  numeric  85799      0           0.0
# 196           return_4d_realty_cube  numeric  85799      0           0.0
# 197            return_5d_realty_sqr  numeric  85799      0           0.0
# 198           return_5d_realty_cube  numeric  85799      0           0.0
# 199            Voltality_realty_log  numeric  85799      0           0.0
# 200               Voltality_psu_log  numeric  85799      0           0.0
# 201               return_1d_500_sqr  numeric  85799      0           0.0
# 202               return_2d_500_sqr  numeric  85799      0           0.0
# 203               return_3d_500_sqr  numeric  85799      0           0.0
# 204               return_4d_500_sqr  numeric  85799      0           0.0
# 205               return_5d_500_sqr  numeric  85799      0           0.0
# 206               Voltality_500_log  numeric  85799      0           0.0
# 207                   Voltality_log  numeric  85799      0           0.0
# 208                    Sector_dum_0  numeric  85799      0           0.0
# 209                    Sector_dum_1  numeric  85799      0           0.0
# 210                    Sector_dum_2  numeric  85799      0           0.0
# 211                    Sector_dum_3  numeric  85799      0           0.0
#
#      unique          std   skewness    kurtosis         mean  \
# 0     39664     0.027459   7.091632   63.540422     0.013701
# 1     32593     0.027816   7.090556   63.469359     0.013879
# 2     34046     0.027121   7.097248   63.691628     0.013529
# 3     31911     0.027451   7.091405   63.542587     0.013699
# 4     39665  2747.020650   7.088134   63.474589  1370.711168
# 5     67502     0.027466   7.091982   63.551500     0.013706
# 6     84156     0.005535  11.596452  350.706477     0.003203
# 7     84942  2285.277093  15.333428  783.738028  1690.339774
# 8     57871     0.003915   1.470718    5.484016     0.004906
# 9     83421     0.002721  15.653928  673.436033     0.001591
# 10     7585     0.163001  -0.268561    2.522475     0.530885
# 11     1695     0.018279   0.089058    1.925101     0.079260
# 12     1696     0.018290   0.088750    1.925852     0.079624
# 13     1693     0.018209   0.089480    1.922979     0.078782
# 14     1693     0.018246   0.090184    1.924256     0.079209
# 15     1698     0.068611   1.239009    5.021415     0.188149
# 16     2484     0.379066   1.674908    7.742622     0.871171
# 17     1681     0.025266  -0.147432    1.665943     0.077355
# 18     1684     0.025332  -0.153896    1.664574     0.077835
# 19     1685     0.025079  -0.144575    1.668992     0.076738
# 20     1681     0.025184  -0.149948    1.666246     0.077272
# 21     1690     0.055464   0.263789    1.863650     0.173748
# 22     1688     0.055582   0.263283    1.865037     0.174958
# 23     1690     0.055299   0.267390    1.868270     0.172359
# 24     1689     0.055437   0.265399    1.865088     0.173673
# 25     1708     0.050378   0.219684    2.506480     0.203127
# 26     1709     0.050586   0.219230    2.509289     0.204466
# 27     1705     0.049995   0.221811    2.497315     0.201597
# 28     1704     0.050281   0.222041    2.507937     0.203056
# 29     1679     0.024896  -0.123356    2.496375     0.101178
# ..      ...          ...        ...         ...          ...
# 182    2505     1.957387   5.939692   60.789075     1.002087
# 183    2525     7.572996  -8.508883  211.695539    -0.141126
# 184    2505     1.957391   5.939650   60.788550     1.002089
# 185    2505     1.957852   5.933698   60.713356     1.003618
# 186    2505     1.957889   5.931827   60.695526     1.004704
# 187    1708     0.481113  -0.479899    3.151601    -0.065102
# 188    1722     0.493194  -0.180622    3.034748    -0.280339
# 189    2488     6.703091   3.930399   23.469942     3.593651
# 190    2505    41.330972  -1.665374   54.329952    -2.406270
# 191    2488     6.702705   3.930591   23.472454     3.594873
# 192    2505    41.330960  -1.665219   54.329664    -2.408433
# 193    2488     6.703108   3.930256   23.469181     3.593884
# 194    2505    41.331056  -1.665346   54.329470    -2.406511
# 195    2488     6.708091   3.921503   23.391161     3.602066
# 196    2505    41.358815  -1.660957   54.202138    -2.374616
# 197    2488     6.708447   3.921455   23.389334     3.600737
# 198    2505    41.358907  -1.661151   54.202100    -2.371894
# 199    1703     0.495429  -0.161190    2.996940     0.281964
# 200    1717     0.488562  -0.180316    3.123122     0.305827
# 201    2500     1.302598   6.254376   66.958215     0.633834
# 202    2500     1.302644   6.253929   66.950942     0.633721
# 203    2500     1.302651   6.253841   66.949676     0.633713
# 204    2500     1.305870   6.217212   66.292997     0.635942
# 205    2500     1.305956   6.217604   66.288249     0.635321
# 206    1721     0.516537  -0.251699    3.122689    -0.596314
# 207   85290     0.529774  -0.242642    3.179914     0.207170
# 208       2     0.498668   0.146430    1.021442     0.463490
# 209       2     0.492828   0.342518    1.117319     0.415599
# 210       2     0.489561   0.415274    1.172452     0.398350
# 211       2     0.398960   1.510860    3.282697     0.198615
#
#             ...                   p5         p10          p50          p90  \
# 0           ...             0.001510    0.002053     0.006596     0.028240
# 1           ...             0.001537    0.002086     0.006690     0.028580
# 2           ...             0.001488    0.002021     0.006501     0.027937
# 3           ...             0.001511    0.002054     0.006595     0.028225
# 4           ...           151.050000  205.340000   659.850000  2824.430000
# 5           ...             0.001511    0.002055     0.006600     0.028250
# 6           ...             0.000059    0.000163     0.001621     0.007672
# 7           ...           100.646209  228.526617  1071.267842  3716.939745
# 8           ...             0.000480    0.000989     0.003896     0.010073
# 9           ...             0.000031    0.000079     0.000836     0.003806
# 10          ...             0.240600    0.301700     0.544500     0.734400
# 11          ...             0.052400    0.054802     0.080770     0.105520
# 12          ...             0.052637    0.055041     0.081161     0.105963
# 13          ...             0.052014    0.053948     0.080273     0.104898
# 14          ...             0.052344    0.054639     0.080696     0.105398
# 15          ...             0.107949    0.118466     0.174706     0.277896
# 16          ...             0.459238    0.508654     0.787374     1.355645
# 17          ...             0.039641    0.042578     0.082294     0.110319
# 18          ...             0.040017    0.043097     0.082826     0.110740
# 19          ...             0.039448    0.042213     0.081791     0.109430
# 20          ...             0.039692    0.042584     0.082323     0.110058
# 21          ...             0.100254    0.103810     0.173884     0.256323
# 22          ...             0.101309    0.104503     0.175433     0.257236
# 23          ...             0.099018    0.102485     0.172090     0.254951
# 24          ...             0.100207    0.103684     0.173769     0.256018
# 25          ...             0.118645    0.137457     0.199648     0.278599
# 26          ...             0.119895    0.138344     0.200855     0.280996
# 27          ...             0.117314    0.136507     0.197815     0.275891
# 28          ...             0.119099    0.137387     0.199567     0.278645
# 29          ...             0.060126    0.061893     0.105730     0.132579
# ..          ...                  ...         ...          ...          ...
# 182         ...             0.002970    0.009722     0.329384     2.620602
# 183         ...            -4.296456   -1.883989    -0.000044     1.821422
# 184         ...             0.002970    0.009722     0.329384     2.620602
# 185         ...             0.002970    0.009722     0.331535     2.632368
# 186         ...             0.002970    0.009722     0.332305     2.632368
# 187         ...            -0.938484   -0.700081    -0.026245     0.536749
# 188         ...            -1.123606   -0.908944    -0.250344     0.353393
# 189         ...             0.008448    0.036202     1.087540     9.888849
# 190         ...           -38.952376  -14.015333    -0.000555     8.404505
# 191         ...             0.008448    0.036202     1.090443     9.888849
# 192         ...           -38.952376  -14.015333    -0.000555     8.404505
# 193         ...             0.008448    0.036202     1.087540     9.888849
# 194         ...           -38.952376  -14.015333    -0.000555     8.404505
# 195         ...             0.008448    0.036202     1.090443     9.903545
# 196         ...           -38.952376  -14.015333    -0.000555     8.499860
# 197         ...             0.008448    0.036202     1.087540     9.903545
# 198         ...           -38.952376  -14.015333    -0.000555     8.499860
# 199         ...            -0.544434   -0.338505     0.285416     0.920622
# 200         ...            -0.528726   -0.344161     0.326330     0.894517
# 201         ...             0.002079    0.008161     0.198531     1.615719
# 202         ...             0.001949    0.008093     0.198278     1.615719
# 203         ...             0.001949    0.008093     0.198278     1.615719
# 204         ...             0.001949    0.008093     0.198278     1.620728
# 205         ...             0.001949    0.008093     0.197613     1.620728
# 206         ...            -1.465506   -1.265778    -0.564950     0.040481
# 207         ...            -0.712917   -0.476107     0.230760     0.858080
# 208         ...             0.000000    0.000000     0.000000     1.000000
# 209         ...             0.000000    0.000000     0.000000     1.000000
# 210         ...             0.000000    0.000000     0.000000     1.000000
# 211         ...             0.000000    0.000000     0.000000     1.000000
#
#              p95           p99  mean+2sigma  mean+3sigma            max  \
# 0       0.038123      0.167290     0.068619     0.096077       0.327717
# 1       0.038570      0.170206     0.069512     0.097329       0.332826
# 2       0.037714      0.165002     0.067771     0.094892       0.324062
# 3       0.038102      0.167011     0.068601     0.096052       0.327559
# 4    3815.105000  16744.305165  6864.752468  9611.773118   32771.717268
# 5       0.038150      0.167327     0.068638     0.096104       0.328518
# 6       0.011407      0.022897     0.014273     0.019808       0.285201
# 7    5038.070190   9335.882409  6260.893959  8546.171052  187105.785457
# 8       0.012718      0.020087     0.012737     0.016653       0.020087
# 9       0.005514      0.010872     0.007032     0.009753       0.188757
# 10      0.779600      0.871200     0.856887     1.019888       0.871200
# 11      0.108151      0.114750     0.115819     0.134099       0.115855
# 12      0.108348      0.114864     0.116204     0.134495       0.116239
# 13      0.107554      0.114196     0.115199     0.133408       0.115236
# 14      0.108018      0.114500     0.115700     0.133946       0.115734
# 15      0.323969      0.438202     0.325371     0.393982       0.438202
# 16      1.612014      2.190713     1.629302     2.008368       3.513119
# 17      0.113133      0.118681     0.127887     0.153153       0.118681
# 18      0.113725      0.118850     0.128498     0.153830       0.118850
# 19      0.112311      0.117798     0.126895     0.151974       0.117798
# 20      0.112828      0.118432     0.127641     0.152825       0.118432
# 21      0.265672      0.278362     0.284676     0.340140       0.278362
# 22      0.266829      0.279882     0.286122     0.341704       0.279882
# 23      0.264082      0.277660     0.282957     0.338255       0.277660
# 24      0.265196      0.278265     0.284547     0.339984       0.278265
# 25      0.292363      0.313547     0.303883     0.354261       0.313547
# 26      0.293826      0.315059     0.305639     0.356226       0.315059
# 27      0.290415      0.311350     0.301587     0.351581       0.311350
# 28      0.292125      0.313785     0.303618     0.353898       0.313785
# 29      0.145106      0.158971     0.150970     0.175865       0.158971
# ..           ...           ...          ...          ...            ...
# 182     4.233884      8.526619     4.916861     6.874248      30.503681
# 183     3.931067     14.958427    15.004866    22.577863      75.671868
# 184     4.233884      8.526619     4.916871     6.874262      30.503681
# 185     4.233884      8.526619     4.919321     6.877173      30.503681
# 186     4.233884      8.526619     4.920483     6.878372      30.503681
# 187     0.665041      0.899757     0.897125     1.378239       0.914916
# 188     0.506370      0.820500     0.706049     1.199243       1.205209
# 189    15.963491     33.681441    16.999834    23.702925      61.791235
# 190    21.882924    114.432146    80.255673   121.586645     485.724837
# 191    15.963491     33.681441    17.000284    23.702989      61.791235
# 192    21.882924    114.432146    80.253486   121.584446     485.724837
# 193    15.963491     33.681441    17.000099    23.703206      61.791235
# 194    21.882924    114.432146    80.255601   121.586656     485.724837
# 195    15.963491     33.681441    17.018248    23.726338      61.791235
# 196    21.979998    114.432146    80.343013   121.701828     485.724837
# 197    15.963491     33.681441    17.017631    23.726078      61.791235
# 198    21.979998    114.432146    80.345919   121.704826     485.724837
# 199     1.091875      1.377590     1.272822     1.768251       1.377590
# 200     1.066197      1.426614     1.282952     1.771515       1.790498
# 201     2.616937      5.909194     3.239030     4.541629      21.688332
# 202     2.616937      5.909194     3.239010     4.541654      21.688332
# 203     2.616937      5.909194     3.239015     4.541667      21.688332
# 204     2.618691      5.909194     3.247682     4.553552      21.688332
# 205     2.618691      5.909194     3.247233     4.553189      21.688332
# 206     0.212605      0.544873     0.436760     0.953297       0.964988
# 207     1.033361      1.382233     1.266718     1.796492       1.811212
# 208     1.000000      1.000000     1.460827     1.959495       1.000000
# 209     1.000000      1.000000     1.401255     1.894083       1.000000
# 210     1.000000      1.000000     1.377472     1.867033       1.000000
# 211     1.000000      1.000000     0.996536     1.395496       1.000000
#
#      correlation/p_value
# 0               0.999657
# 1               0.999560
# 2               0.999563
# 3               0.999657
# 4               1.000000
# 5               0.999615
# 6              -0.177381
# 7              -0.002421
# 8              -0.152462
# 9              -0.174505
# 10              0.002154
# 11              0.132953
# 12              0.132947
# 13              0.133055
# 14              0.133032
# 15              0.051325
# 16              0.080433
# 17              0.135741
# 18              0.135799
# 19              0.135766
# 20              0.135811
# 21              0.131906
# 22              0.131909
# 23              0.131950
# 24              0.131962
# 25              0.126534
# 26              0.126464
# 27              0.126733
# 28              0.126587
# 29              0.115576
# ..                   ...
# 182            -0.006642
# 183             0.003189
# 184            -0.006327
# 185            -0.006136
# 186            -0.006188
# 187            -0.024413
# 188             0.034748
# 189            -0.020681
# 190             0.000732
# 191            -0.020334
# 192             0.000650
# 193            -0.020174
# 194             0.000872
# 195            -0.020308
# 196             0.000485
# 197            -0.020304
# 198             0.000405
# 199            -0.040528
# 200            -0.005523
# 201            -0.014023
# 202            -0.013836
# 203            -0.013914
# 204            -0.014087
# 205            -0.013902
# 206            -0.033585
# 207            -0.051523
# 208             0.197729
# 209            -0.176346
# 210            -0.035586
# 211            -0.086471
#
# [212 rows x 24 columns]

# %%
os.chdir('../Statistics')

# %%
book = load_workbook('report.xlsx')
writer = pd.ExcelWriter('report.xlsx', engine='openpyxl') 
writer.book = book
writer.sheets = dict((ws.title, ws) for ws in book.worksheets)

edd_df.to_excel(writer, "edd_v03", index=False)

writer.save()

# %%
df.corr()
# Out:
#                                 Prev_Close(in 10^5)  High_1d(in 10^5)  \
# Prev_Close(in 10^5)                        1.000000          0.999925
# High_1d(in 10^5)                           0.999925          1.000000
# Low_1d(in 10^5)                            0.999916          0.999871
# Last_1d(in 10^5)                           0.999995          0.999920
# Close                                      0.999657          0.999560
# VWAP_1d(in 10^5)                           0.999971          0.999961
# Volume_1d(in 10^9)                        -0.177339         -0.177025
# Turnover_1d(in 10^11)                     -0.002095         -0.001500
# Trades_1d(in 10^7)                        -0.152280         -0.151689
# Deliverable_Volume_1d(in 10^9)            -0.174453         -0.174222
# pct_Deliverble_1d                          0.002066          0.001592
# Open_nifty_1d(in 10^5)                     0.133246          0.133027
# High_nifty_1d(in 10^5)                     0.133229          0.132996
# Low_nifty_1d(in 10^5)                      0.133339          0.133069
# Close_nifty_1d(in 10^5)                    0.133307          0.133022
# Volume_nifty_1d(in 10^9)                   0.051307          0.052106
# Turnover_nifty_1d(in 10^11)                0.080585          0.081243
# Open_auto_1d(in 10^5)                      0.135993          0.135642
# High_auto_1d(in 10^5)                      0.136042          0.135678
# Low_auto_1d(in 10^5)                       0.136007          0.135605
# Close_auto_1d(in 10^5)                     0.136047          0.135631
# Open_bank_1d(in 10^5)                      0.132180          0.131914
# High_bank_1d(in 10^5)                      0.132174          0.131899
# Low_bank_1d(in 10^5)                       0.132216          0.131908
# Close_bank_1d(in 10^5)                     0.132219          0.131900
# Open_fmcg_1d(in 10^5)                      0.126829          0.126623
# High_fmcg_1d(in 10^5)                      0.126753          0.126542
# Low_fmcg_1d(in 10^5)                       0.127024          0.126780
# Close_fmcg_1d(in 10^5)                     0.126872          0.126621
# Open_it_1d(in 10^5)                        0.115858          0.115900
# ...                                             ...               ...
# return_2d_it_sqr                          -0.006823         -0.006592
# return_2d_it_cube                          0.003234          0.003111
# return_3d_it_sqr                          -0.006549         -0.006384
# return_4d_it_sqr                          -0.006436         -0.006356
# return_5d_it_sqr                          -0.006188         -0.006146
# Voltality_media_log                       -0.024495         -0.023925
# Voltality_pharma_log                       0.034768          0.035216
# return_1d_realty_sqr                      -0.020523         -0.019423
# return_1d_realty_cube                      0.000543         -0.000522
# return_2d_realty_sqr                      -0.020636         -0.020187
# return_2d_realty_cube                      0.000748          0.000587
# return_3d_realty_sqr                      -0.020245         -0.019992
# return_3d_realty_cube                      0.000607          0.000487
# return_4d_realty_sqr                      -0.020360         -0.020088
# return_4d_realty_cube                      0.000710          0.000439
# return_5d_realty_sqr                      -0.020273         -0.020092
# return_5d_realty_cube                      0.000466          0.000446
# Voltality_realty_log                      -0.040606         -0.039896
# Voltality_psu_log                         -0.005573         -0.004939
# return_1d_500_sqr                         -0.014137         -0.012766
# return_2d_500_sqr                         -0.013953         -0.013473
# return_3d_500_sqr                         -0.013747         -0.013372
# return_4d_500_sqr                         -0.014318         -0.013841
# return_5d_500_sqr                         -0.014030         -0.013745
# Voltality_500_log                         -0.033786         -0.033003
# Voltality_log                             -0.051502         -0.049872
# Sector_dum_0                               0.197724          0.197548
# Sector_dum_1                              -0.176347         -0.175977
# Sector_dum_2                              -0.035559         -0.035595
# Sector_dum_3                              -0.086434         -0.086428
#
#                                 Low_1d(in 10^5)  Last_1d(in 10^5)     Close  \
# Prev_Close(in 10^5)                    0.999916          0.999995  0.999657
# High_1d(in 10^5)                       0.999871          0.999920  0.999560
# Low_1d(in 10^5)                        1.000000          0.999908  0.999563
# Last_1d(in 10^5)                       0.999908          1.000000  0.999657
# Close                                  0.999563          0.999657  1.000000
# VWAP_1d(in 10^5)                       0.999956          0.999964  0.999615
# Volume_1d(in 10^9)                    -0.177659         -0.177355 -0.177381
# Turnover_1d(in 10^11)                 -0.002955         -0.002122 -0.002421
# Trades_1d(in 10^7)                    -0.153016         -0.152296 -0.152462
# Deliverable_Volume_1d(in 10^9)        -0.174643         -0.174471 -0.174505
# pct_Deliverble_1d                      0.003038          0.002067  0.002154
# Open_nifty_1d(in 10^5)                 0.133611          0.133261  0.132953
# High_nifty_1d(in 10^5)                 0.133559          0.133245  0.132947
# Low_nifty_1d(in 10^5)                  0.133709          0.133353  0.133055
# Close_nifty_1d(in 10^5)                0.133624          0.133323  0.133032
# Volume_nifty_1d(in 10^9)               0.050488          0.051319  0.051325
# Turnover_nifty_1d(in 10^11)            0.079919          0.080596  0.080433
# Open_auto_1d(in 10^5)                  0.136478          0.136010  0.135741
# High_auto_1d(in 10^5)                  0.136493          0.136060  0.135799
# Low_auto_1d(in 10^5)                   0.136493          0.136024  0.135766
# Close_auto_1d(in 10^5)                 0.136484          0.136065  0.135811
# Open_bank_1d(in 10^5)                  0.132577          0.132195  0.131906
# High_bank_1d(in 10^5)                  0.132537          0.132190  0.131909
# Low_bank_1d(in 10^5)                   0.132616          0.132230  0.131950
# Close_bank_1d(in 10^5)                 0.132574          0.132236  0.131962
# Open_fmcg_1d(in 10^5)                  0.127167          0.126845  0.126534
# High_fmcg_1d(in 10^5)                  0.127064          0.126770  0.126464
# Low_fmcg_1d(in 10^5)                   0.127365          0.127040  0.126733
# Close_fmcg_1d(in 10^5)                 0.127180          0.126890  0.126587
# Open_it_1d(in 10^5)                    0.115931          0.115873  0.115576
# ...                                         ...               ...       ...
# return_2d_it_sqr                      -0.007048         -0.006844 -0.006642
# return_2d_it_cube                      0.003349          0.003245  0.003189
# return_3d_it_sqr                      -0.006867         -0.006551 -0.006327
# return_4d_it_sqr                      -0.006662         -0.006440 -0.006136
# return_5d_it_sqr                      -0.006407         -0.006177 -0.006188
# Voltality_media_log                   -0.025185         -0.024476 -0.024413
# Voltality_pharma_log                   0.034243          0.034798  0.034748
# return_1d_realty_sqr                  -0.020887         -0.020477 -0.020681
# return_1d_realty_cube                  0.000204          0.000491  0.000732
# return_2d_realty_sqr                  -0.021138         -0.020602 -0.020334
# return_2d_realty_cube                  0.000923          0.000705  0.000650
# return_3d_realty_sqr                  -0.020642         -0.020239 -0.020174
# return_3d_realty_cube                  0.000823          0.000591  0.000872
# return_4d_realty_sqr                  -0.020603         -0.020365 -0.020308
# return_4d_realty_cube                  0.000742          0.000707  0.000485
# return_5d_realty_sqr                  -0.020475         -0.020280 -0.020304
# return_5d_realty_cube                  0.000704          0.000462  0.000405
# Voltality_realty_log                  -0.041256         -0.040593 -0.040528
# Voltality_psu_log                     -0.006333         -0.005540 -0.005523
# return_1d_500_sqr                     -0.014851         -0.014086 -0.014023
# return_2d_500_sqr                     -0.014621         -0.013928 -0.013836
# return_3d_500_sqr                     -0.014213         -0.013736 -0.013914
# return_4d_500_sqr                     -0.014657         -0.014317 -0.014087
# return_5d_500_sqr                     -0.014510         -0.014020 -0.013902
# Voltality_500_log                     -0.034806         -0.033759 -0.033585
# Voltality_log                         -0.053384         -0.051498 -0.051523
# Sector_dum_0                           0.197949          0.197726  0.197729
# Sector_dum_1                          -0.176627         -0.176357 -0.176346
# Sector_dum_2                          -0.035584         -0.035530 -0.035586
# Sector_dum_3                          -0.086423         -0.086445 -0.086471
#
#                                 VWAP_1d(in 10^5)  Volume_1d(in 10^9)  \
# Prev_Close(in 10^5)                     0.999971           -0.177339
# High_1d(in 10^5)                        0.999961           -0.177025
# Low_1d(in 10^5)                         0.999956           -0.177659
# Last_1d(in 10^5)                        0.999964           -0.177355
# Close                                   0.999615           -0.177381
# VWAP_1d(in 10^5)                        1.000000           -0.177361
# Volume_1d(in 10^9)                     -0.177361            1.000000
# Turnover_1d(in 10^11)                  -0.002196            0.672318
# Trades_1d(in 10^7)                     -0.152350            0.609245
# Deliverable_Volume_1d(in 10^9)         -0.174473            0.894308
# pct_Deliverble_1d                       0.002130           -0.120816
# Open_nifty_1d(in 10^5)                  0.133298            0.173239
# High_nifty_1d(in 10^5)                  0.133265            0.174105
# Low_nifty_1d(in 10^5)                   0.133371            0.171905
# Close_nifty_1d(in 10^5)                 0.133315            0.173082
# Volume_nifty_1d(in 10^9)                0.051299            0.250535
# Turnover_nifty_1d(in 10^11)             0.080602            0.255612
# Open_auto_1d(in 10^5)                   0.136033            0.150024
# High_auto_1d(in 10^5)                   0.136066            0.150711
# Low_auto_1d(in 10^5)                    0.136028            0.148564
# Close_auto_1d(in 10^5)                  0.136044            0.149591
# Open_bank_1d(in 10^5)                   0.132225            0.173658
# High_bank_1d(in 10^5)                   0.132204            0.174750
# Low_bank_1d(in 10^5)                    0.132244            0.172619
# Close_bank_1d(in 10^5)                  0.132226            0.173788
# Open_fmcg_1d(in 10^5)                   0.126871            0.178769
# High_fmcg_1d(in 10^5)                   0.126785            0.179367
# Low_fmcg_1d(in 10^5)                    0.127054            0.177546
# Close_fmcg_1d(in 10^5)                  0.126887            0.178425
# Open_it_1d(in 10^5)                     0.115905            0.169387
# ...                                          ...                 ...
# return_2d_it_sqr                       -0.006826            0.018099
# return_2d_it_cube                       0.003224            0.001004
# return_3d_it_sqr                       -0.006600            0.016190
# return_4d_it_sqr                       -0.006502            0.020049
# return_5d_it_sqr                       -0.006287            0.013370
# Voltality_media_log                    -0.024509            0.011578
# Voltality_pharma_log                    0.034766            0.084391
# return_1d_realty_sqr                   -0.020185            0.011172
# return_1d_realty_cube                  -0.000038           -0.015379
# return_2d_realty_sqr                   -0.020660           -0.002469
# return_2d_realty_cube                   0.000804           -0.003540
# return_3d_realty_sqr                   -0.020297           -0.006369
# return_3d_realty_cube                   0.000644           -0.004943
# return_4d_realty_sqr                   -0.020360           -0.005799
# return_4d_realty_cube                   0.000624           -0.011419
# return_5d_realty_sqr                   -0.020279           -0.014001
# return_5d_realty_cube                   0.000564           -0.008061
# Voltality_realty_log                   -0.040546           -0.016442
# Voltality_psu_log                      -0.005611            0.051833
# return_1d_500_sqr                      -0.013790            0.034354
# return_2d_500_sqr                      -0.014055            0.022245
# return_3d_500_sqr                      -0.013794            0.013719
# return_4d_500_sqr                      -0.014300            0.018102
# return_5d_500_sqr                      -0.014125            0.009108
# Voltality_500_log                      -0.033849            0.014438
# Voltality_log                          -0.051566            0.173428
# Sector_dum_0                            0.197748           -0.177989
# Sector_dum_1                           -0.176314            0.011372
# Sector_dum_2                           -0.035572           -0.168751
# Sector_dum_3                           -0.086441           -0.046699
#
#                                 Turnover_1d(in 10^11)  Trades_1d(in 10^7)  \
# Prev_Close(in 10^5)                         -0.002095           -0.152280
# High_1d(in 10^5)                            -0.001500           -0.151689
# Low_1d(in 10^5)                             -0.002955           -0.153016
# Last_1d(in 10^5)                            -0.002122           -0.152296
# Close                                       -0.002421           -0.152462
# VWAP_1d(in 10^5)                            -0.002196           -0.152350
# Volume_1d(in 10^9)                           0.672318            0.609245
# Turnover_1d(in 10^11)                        1.000000            0.724384
# Trades_1d(in 10^7)                           0.724384            1.000000
# Deliverable_Volume_1d(in 10^9)               0.665006            0.554251
# pct_Deliverble_1d                           -0.057854           -0.081447
# Open_nifty_1d(in 10^5)                       0.236339            0.240205
# High_nifty_1d(in 10^5)                       0.237385            0.241663
# Low_nifty_1d(in 10^5)                        0.234796            0.238278
# Close_nifty_1d(in 10^5)                      0.236157            0.240037
# Volume_nifty_1d(in 10^9)                     0.291227            0.326679
# Turnover_nifty_1d(in 10^11)                  0.332989            0.341782
# Open_auto_1d(in 10^5)                        0.205356            0.200605
# High_auto_1d(in 10^5)                        0.206114            0.201830
# Low_auto_1d(in 10^5)                         0.203646            0.198488
# Close_auto_1d(in 10^5)                       0.204736            0.200089
# Open_bank_1d(in 10^5)                        0.236240            0.237129
# High_bank_1d(in 10^5)                        0.237584            0.238797
# Low_bank_1d(in 10^5)                         0.235008            0.235627
# Close_bank_1d(in 10^5)                       0.236383            0.237318
# Open_fmcg_1d(in 10^5)                        0.238320            0.252279
# High_fmcg_1d(in 10^5)                        0.239012            0.253292
# Low_fmcg_1d(in 10^5)                         0.236982            0.250387
# Close_fmcg_1d(in 10^5)                       0.237944            0.251837
# Open_it_1d(in 10^5)                          0.221554            0.248802
# ...                                               ...                 ...
# return_2d_it_sqr                             0.023517            0.039250
# return_2d_it_cube                            0.000663           -0.003479
# return_3d_it_sqr                             0.015920            0.037015
# return_4d_it_sqr                             0.020589            0.036354
# return_5d_it_sqr                             0.014259            0.026966
# Voltality_media_log                         -0.000785            0.039094
# Voltality_pharma_log                         0.104267            0.143340
# return_1d_realty_sqr                         0.012852            0.031084
# return_1d_realty_cube                       -0.020537           -0.017582
# return_2d_realty_sqr                        -0.006667            0.017476
# return_2d_realty_cube                       -0.005651           -0.017337
# return_3d_realty_sqr                        -0.009001            0.013038
# return_3d_realty_cube                       -0.008597           -0.009404
# return_4d_realty_sqr                        -0.008955            0.005860
# return_4d_realty_cube                       -0.013835           -0.018202
# return_5d_realty_sqr                        -0.020758           -0.009716
# return_5d_realty_cube                       -0.007680           -0.014717
# Voltality_realty_log                        -0.024656            0.005984
# Voltality_psu_log                            0.051361            0.089283
# return_1d_500_sqr                            0.035041            0.062037
# return_2d_500_sqr                            0.017776            0.054904
# return_3d_500_sqr                            0.007239            0.036360
# return_4d_500_sqr                            0.012721            0.041354
# return_5d_500_sqr                            0.001728            0.026015
# Voltality_500_log                            0.001908            0.047844
# Voltality_log                                0.102497            0.181930
# Sector_dum_0                                -0.049831           -0.091722
# Sector_dum_1                                -0.079045           -0.026010
# Sector_dum_2                                -0.039332           -0.054246
# Sector_dum_3                                -0.140840           -0.128477
#
#                                 Deliverable_Volume_1d(in 10^9)      ...       \
# Prev_Close(in 10^5)                                  -0.174453      ...
# High_1d(in 10^5)                                     -0.174222      ...
# Low_1d(in 10^5)                                      -0.174643      ...
# Last_1d(in 10^5)                                     -0.174471      ...
# Close                                                -0.174505      ...
# VWAP_1d(in 10^5)                                     -0.174473      ...
# Volume_1d(in 10^9)                                    0.894308      ...
# Turnover_1d(in 10^11)                                 0.665006      ...
# Trades_1d(in 10^7)                                    0.554251      ...
# Deliverable_Volume_1d(in 10^9)                        1.000000      ...
# pct_Deliverble_1d                                     0.101429      ...
# Open_nifty_1d(in 10^5)                                0.139596      ...
# High_nifty_1d(in 10^5)                                0.140296      ...
# Low_nifty_1d(in 10^5)                                 0.138491      ...
# Close_nifty_1d(in 10^5)                               0.139348      ...
# Volume_nifty_1d(in 10^9)                              0.229677      ...
# Turnover_nifty_1d(in 10^11)                           0.236447      ...
# Open_auto_1d(in 10^5)                                 0.129414      ...
# High_auto_1d(in 10^5)                                 0.129911      ...
# Low_auto_1d(in 10^5)                                  0.128231      ...
# Close_auto_1d(in 10^5)                                0.128942      ...
# Open_bank_1d(in 10^5)                                 0.140539      ...
# High_bank_1d(in 10^5)                                 0.141456      ...
# Low_bank_1d(in 10^5)                                  0.139602      ...
# Close_bank_1d(in 10^5)                                0.140531      ...
# Open_fmcg_1d(in 10^5)                                 0.139386      ...
# High_fmcg_1d(in 10^5)                                 0.139864      ...
# Low_fmcg_1d(in 10^5)                                  0.138310      ...
# Close_fmcg_1d(in 10^5)                                0.138984      ...
# Open_it_1d(in 10^5)                                   0.126848      ...
# ...                                                        ...      ...
# return_2d_it_sqr                                      0.010093      ...
# return_2d_it_cube                                    -0.000516      ...
# return_3d_it_sqr                                      0.007509      ...
# return_4d_it_sqr                                      0.014481      ...
# return_5d_it_sqr                                      0.007205      ...
# Voltality_media_log                                   0.005046      ...
# Voltality_pharma_log                                  0.066754      ...
# return_1d_realty_sqr                                  0.016587      ...
# return_1d_realty_cube                                -0.016202      ...
# return_2d_realty_sqr                                 -0.003354      ...
# return_2d_realty_cube                                -0.001601      ...
# return_3d_realty_sqr                                 -0.003225      ...
# return_3d_realty_cube                                -0.005963      ...
# return_4d_realty_sqr                                 -0.000807      ...
# return_4d_realty_cube                                -0.012673      ...
# return_5d_realty_sqr                                 -0.012313      ...
# return_5d_realty_cube                                -0.008304      ...
# Voltality_realty_log                                 -0.015704      ...
# Voltality_psu_log                                     0.039033      ...
# return_1d_500_sqr                                     0.031916      ...
# return_2d_500_sqr                                     0.014237      ...
# return_3d_500_sqr                                     0.006019      ...
# return_4d_500_sqr                                     0.016687      ...
# return_5d_500_sqr                                     0.003769      ...
# Voltality_500_log                                     0.004099      ...
# Voltality_log                                         0.091324      ...
# Sector_dum_0                                         -0.157479      ...
# Sector_dum_1                                         -0.016769      ...
# Sector_dum_2                                         -0.119418      ...
# Sector_dum_3                                          0.001777      ...
#
#                                 return_2d_500_sqr  return_3d_500_sqr  \
# Prev_Close(in 10^5)                     -0.013953          -0.013747
# High_1d(in 10^5)                        -0.013473          -0.013372
# Low_1d(in 10^5)                         -0.014621          -0.014213
# Last_1d(in 10^5)                        -0.013928          -0.013736
# Close                                   -0.013836          -0.013914
# VWAP_1d(in 10^5)                        -0.014055          -0.013794
# Volume_1d(in 10^9)                       0.022245           0.013719
# Turnover_1d(in 10^11)                    0.017776           0.007239
# Trades_1d(in 10^7)                       0.054904           0.036360
# Deliverable_Volume_1d(in 10^9)           0.014237           0.006019
# pct_Deliverble_1d                       -0.024013          -0.018829
# Open_nifty_1d(in 10^5)                  -0.092135          -0.090043
# High_nifty_1d(in 10^5)                  -0.090622          -0.087955
# Low_nifty_1d(in 10^5)                   -0.094929          -0.092028
# Close_nifty_1d(in 10^5)                 -0.091729          -0.089791
# Volume_nifty_1d(in 10^9)                 0.143123           0.111621
# Turnover_nifty_1d(in 10^11)              0.058982           0.029896
# Open_auto_1d(in 10^5)                   -0.095653          -0.094681
# High_auto_1d(in 10^5)                   -0.093410          -0.092568
# Low_auto_1d(in 10^5)                    -0.099234          -0.096885
# Close_auto_1d(in 10^5)                  -0.095503          -0.094470
# Open_bank_1d(in 10^5)                   -0.095026          -0.092462
# High_bank_1d(in 10^5)                   -0.092845          -0.090007
# Low_bank_1d(in 10^5)                    -0.096880          -0.094186
# Close_bank_1d(in 10^5)                  -0.093745          -0.091909
# Open_fmcg_1d(in 10^5)                   -0.084739          -0.084309
# High_fmcg_1d(in 10^5)                   -0.083474          -0.083519
# Low_fmcg_1d(in 10^5)                    -0.088377          -0.086298
# Close_fmcg_1d(in 10^5)                  -0.085603          -0.085050
# Open_it_1d(in 10^5)                     -0.034689          -0.034661
# ...                                           ...                ...
# return_2d_it_sqr                         0.181257           0.041708
# return_2d_it_cube                       -0.011486           0.008186
# return_3d_it_sqr                         0.034013           0.181263
# return_4d_it_sqr                         0.062991           0.033687
# return_5d_it_sqr                         0.013500           0.062761
# Voltality_media_log                      0.206097           0.219700
# Voltality_pharma_log                     0.185582           0.180536
# return_1d_realty_sqr                     0.109154           0.065299
# return_1d_realty_cube                    0.045464           0.045233
# return_2d_realty_sqr                     0.483992           0.109086
# return_2d_realty_cube                   -0.325467           0.045485
# return_3d_realty_sqr                     0.062427           0.484027
# return_3d_realty_cube                    0.009610          -0.325481
# return_4d_realty_sqr                     0.036480           0.061918
# return_4d_realty_cube                   -0.042282           0.009325
# return_5d_realty_sqr                     0.074114           0.036570
# return_5d_realty_cube                   -0.087329          -0.042315
# Voltality_realty_log                     0.235560           0.253241
# Voltality_psu_log                        0.254655           0.259791
# return_1d_500_sqr                        0.054488           0.084730
# return_2d_500_sqr                        1.000000           0.054524
# return_3d_500_sqr                        0.054524           1.000000
# return_4d_500_sqr                        0.083698           0.053671
# return_5d_500_sqr                        0.159276           0.083908
# Voltality_500_log                        0.388898           0.397184
# Voltality_log                            0.151157           0.156381
# Sector_dum_0                             0.000178           0.000083
# Sector_dum_1                            -0.000188          -0.000204
# Sector_dum_2                            -0.000093          -0.000025
# Sector_dum_3                            -0.000026          -0.000081
#
#                                 return_4d_500_sqr  return_5d_500_sqr  \
# Prev_Close(in 10^5)                     -0.014318          -0.014030
# High_1d(in 10^5)                        -0.013841          -0.013745
# Low_1d(in 10^5)                         -0.014657          -0.014510
# Last_1d(in 10^5)                        -0.014317          -0.014020
# Close                                   -0.014087          -0.013902
# VWAP_1d(in 10^5)                        -0.014300          -0.014125
# Volume_1d(in 10^9)                       0.018102           0.009108
# Turnover_1d(in 10^11)                    0.012721           0.001728
# Trades_1d(in 10^7)                       0.041354           0.026015
# Deliverable_Volume_1d(in 10^9)           0.016687           0.003769
# pct_Deliverble_1d                        0.000731          -0.019695
# Open_nifty_1d(in 10^5)                  -0.091499          -0.092312
# High_nifty_1d(in 10^5)                  -0.091055          -0.090283
# Low_nifty_1d(in 10^5)                   -0.094418          -0.094416
# Close_nifty_1d(in 10^5)                 -0.093588          -0.092000
# Volume_nifty_1d(in 10^9)                 0.124837           0.078264
# Turnover_nifty_1d(in 10^11)              0.040996           0.010275
# Open_auto_1d(in 10^5)                   -0.096448          -0.098390
# High_auto_1d(in 10^5)                   -0.096742          -0.096403
# Low_auto_1d(in 10^5)                    -0.100081          -0.099768
# Close_auto_1d(in 10^5)                  -0.099535          -0.097590
# Open_bank_1d(in 10^5)                   -0.093341          -0.093847
# High_bank_1d(in 10^5)                   -0.092744          -0.092659
# Low_bank_1d(in 10^5)                    -0.095839          -0.096245
# Close_bank_1d(in 10^5)                  -0.094749          -0.094703
# Open_fmcg_1d(in 10^5)                   -0.087526          -0.088302
# High_fmcg_1d(in 10^5)                   -0.087483          -0.086108
# Low_fmcg_1d(in 10^5)                    -0.090495          -0.090041
# Close_fmcg_1d(in 10^5)                  -0.089514          -0.087071
# Open_it_1d(in 10^5)                     -0.038068          -0.038473
# ...                                           ...                ...
# return_2d_it_sqr                         0.023200          -0.007012
# return_2d_it_cube                       -0.018850          -0.009000
# return_3d_it_sqr                         0.040830           0.023432
# return_4d_it_sqr                         0.182401           0.040662
# return_5d_it_sqr                         0.034457           0.182340
# Voltality_media_log                      0.225494           0.215846
# Voltality_pharma_log                     0.184389           0.198488
# return_1d_realty_sqr                     0.093505           0.040762
# return_1d_realty_cube                   -0.061732          -0.005370
# return_2d_realty_sqr                     0.064866           0.093645
# return_2d_realty_cube                    0.045055          -0.061727
# return_3d_realty_sqr                     0.107933           0.065055
# return_3d_realty_cube                    0.045464           0.045048
# return_4d_realty_sqr                     0.484988           0.107729
# return_4d_realty_cube                   -0.322296           0.045255
# return_5d_realty_sqr                     0.061100           0.485084
# return_5d_realty_cube                    0.009359          -0.322291
# Voltality_realty_log                     0.264668           0.256136
# Voltality_psu_log                        0.254579           0.252312
# return_1d_500_sqr                        0.159096           0.102151
# return_2d_500_sqr                        0.083698           0.159276
# return_3d_500_sqr                        0.053671           0.083908
# return_4d_500_sqr                        1.000000           0.052751
# return_5d_500_sqr                        0.052751           1.000000
# Voltality_500_log                        0.396250           0.398818
# Voltality_log                            0.155300           0.159072
# Sector_dum_0                             0.000148           0.000189
# Sector_dum_1                            -0.000221          -0.000237
# Sector_dum_2                            -0.000030          -0.000051
# Sector_dum_3                            -0.000090          -0.000102
#
#                                 Voltality_500_log  Voltality_log  \
# Prev_Close(in 10^5)                     -0.033786      -0.051502
# High_1d(in 10^5)                        -0.033003      -0.049872
# Low_1d(in 10^5)                         -0.034806      -0.053384
# Last_1d(in 10^5)                        -0.033759      -0.051498
# Close                                   -0.033585      -0.051523
# VWAP_1d(in 10^5)                        -0.033849      -0.051566
# Volume_1d(in 10^9)                       0.014438       0.173428
# Turnover_1d(in 10^11)                    0.001908       0.102497
# Trades_1d(in 10^7)                       0.047844       0.181930
# Deliverable_Volume_1d(in 10^9)           0.004099       0.091324
# pct_Deliverble_1d                       -0.034459      -0.264305
# Open_nifty_1d(in 10^5)                  -0.227796      -0.087418
# High_nifty_1d(in 10^5)                  -0.222552      -0.085462
# Low_nifty_1d(in 10^5)                   -0.233944      -0.089918
# Close_nifty_1d(in 10^5)                 -0.227868      -0.087449
# Volume_nifty_1d(in 10^9)                 0.155476       0.124124
# Turnover_nifty_1d(in 10^11)              0.021126       0.055081
# Open_auto_1d(in 10^5)                   -0.250311      -0.113244
# High_auto_1d(in 10^5)                   -0.245976      -0.111370
# Low_auto_1d(in 10^5)                    -0.255713      -0.115442
# Close_auto_1d(in 10^5)                  -0.250128      -0.113186
# Open_bank_1d(in 10^5)                   -0.235555      -0.098767
# High_bank_1d(in 10^5)                   -0.230521      -0.096677
# Low_bank_1d(in 10^5)                    -0.240930      -0.101012
# Close_bank_1d(in 10^5)                  -0.235275      -0.098599
# Open_fmcg_1d(in 10^5)                   -0.222687      -0.079083
# High_fmcg_1d(in 10^5)                   -0.218900      -0.077285
# Low_fmcg_1d(in 10^5)                    -0.226798      -0.081630
# Close_fmcg_1d(in 10^5)                  -0.222362      -0.079350
# Open_it_1d(in 10^5)                     -0.097852      -0.015535
# ...                                           ...            ...
# return_2d_it_sqr                         0.102686       0.071641
# return_2d_it_cube                       -0.009947      -0.018866
# return_3d_it_sqr                         0.128632       0.083189
# return_4d_it_sqr                         0.120628       0.081542
# return_5d_it_sqr                         0.117203       0.082668
# Voltality_media_log                      0.402622       0.187276
# Voltality_pharma_log                     0.329606       0.154754
# return_1d_realty_sqr                     0.231776       0.106085
# return_1d_realty_cube                   -0.075286      -0.014688
# return_2d_realty_sqr                     0.256143       0.112351
# return_2d_realty_cube                   -0.069658      -0.017010
# return_3d_realty_sqr                     0.267347       0.118144
# return_3d_realty_cube                   -0.089905      -0.022257
# return_4d_realty_sqr                     0.268663       0.116805
# return_4d_realty_cube                   -0.097987      -0.025430
# return_5d_realty_sqr                     0.243094       0.111232
# return_5d_realty_cube                   -0.120691      -0.037471
# Voltality_realty_log                     0.533496       0.202971
# Voltality_psu_log                        0.534589       0.235460
# return_1d_500_sqr                        0.399386       0.146193
# return_2d_500_sqr                        0.388898       0.151157
# return_3d_500_sqr                        0.397184       0.156381
# return_4d_500_sqr                        0.396250       0.155300
# return_5d_500_sqr                        0.398818       0.159072
# Voltality_500_log                        1.000000       0.291666
# Voltality_log                            0.291666       1.000000
# Sector_dum_0                             0.001116      -0.061989
# Sector_dum_1                            -0.001423       0.143954
# Sector_dum_2                            -0.000566      -0.058018
# Sector_dum_3                            -0.000518       0.028835
#
#                                 Sector_dum_0  Sector_dum_1  Sector_dum_2  \
# Prev_Close(in 10^5)                 0.197724     -0.176347     -0.035559
# High_1d(in 10^5)                    0.197548     -0.175977     -0.035595
# Low_1d(in 10^5)                     0.197949     -0.176627     -0.035584
# Last_1d(in 10^5)                    0.197726     -0.176357     -0.035530
# Close                               0.197729     -0.176346     -0.035586
# VWAP_1d(in 10^5)                    0.197748     -0.176314     -0.035572
# Volume_1d(in 10^9)                 -0.177989      0.011372     -0.168751
# Turnover_1d(in 10^11)              -0.049831     -0.079045     -0.039332
# Trades_1d(in 10^7)                 -0.091722     -0.026010     -0.054246
# Deliverable_Volume_1d(in 10^9)     -0.157479     -0.016769     -0.119418
# pct_Deliverble_1d                   0.082431     -0.113328      0.191151
# Open_nifty_1d(in 10^5)             -0.009353      0.011932      0.004111
# High_nifty_1d(in 10^5)             -0.009365      0.011948      0.004118
# Low_nifty_1d(in 10^5)              -0.009342      0.011919      0.004107
# Close_nifty_1d(in 10^5)            -0.009351      0.011930      0.004114
# Volume_nifty_1d(in 10^9)           -0.003681      0.004696      0.001874
# Turnover_nifty_1d(in 10^11)        -0.005118      0.006522      0.002416
# Open_auto_1d(in 10^5)              -0.009690      0.012363      0.004437
# High_auto_1d(in 10^5)              -0.009707      0.012385      0.004445
# Low_auto_1d(in 10^5)               -0.009684      0.012355      0.004436
# Close_auto_1d(in 10^5)             -0.009697      0.012372      0.004442
# Open_bank_1d(in 10^5)              -0.008177      0.010432      0.003595
# High_bank_1d(in 10^5)              -0.008193      0.010453      0.003605
# Low_bank_1d(in 10^5)               -0.008161      0.010411      0.003590
# Close_bank_1d(in 10^5)             -0.008175      0.010430      0.003600
# Open_fmcg_1d(in 10^5)              -0.009460      0.012069      0.003582
# High_fmcg_1d(in 10^5)              -0.009460      0.012070      0.003579
# Low_fmcg_1d(in 10^5)               -0.009442      0.012046      0.003580
# Close_fmcg_1d(in 10^5)             -0.009447      0.012052      0.003576
# Open_it_1d(in 10^5)                -0.010785      0.013759      0.004822
# ...                                      ...           ...           ...
# return_2d_it_sqr                    0.000092     -0.000015     -0.000051
# return_2d_it_cube                  -0.000156      0.000216      0.000045
# return_3d_it_sqr                    0.000010     -0.000020     -0.000095
# return_4d_it_sqr                    0.000083     -0.000032     -0.000056
# return_5d_it_sqr                    0.000054     -0.000051     -0.000030
# Voltality_media_log                 0.000919     -0.001173     -0.000549
# Voltality_pharma_log               -0.004180      0.005332      0.001629
# return_1d_realty_sqr                0.000800     -0.001013     -0.000624
# return_1d_realty_cube               0.000503     -0.000655     -0.000040
# return_2d_realty_sqr                0.000794     -0.001007     -0.000633
# return_2d_realty_cube               0.000430     -0.000610     -0.000049
# return_3d_realty_sqr                0.000787     -0.001007     -0.000626
# return_3d_realty_cube               0.000467     -0.000595     -0.000043
# return_4d_realty_sqr                0.000768     -0.000977     -0.000560
# return_4d_realty_cube               0.000442     -0.000581      0.000029
# return_5d_realty_sqr                0.000755     -0.000947     -0.000523
# return_5d_realty_cube               0.000461     -0.000524     -0.000020
# Voltality_realty_log                0.002045     -0.002609     -0.001280
# Voltality_psu_log                  -0.001262      0.001611      0.000487
# return_1d_500_sqr                   0.000115     -0.000130     -0.000063
# return_2d_500_sqr                   0.000178     -0.000188     -0.000093
# return_3d_500_sqr                   0.000083     -0.000204     -0.000025
# return_4d_500_sqr                   0.000148     -0.000221     -0.000030
# return_5d_500_sqr                   0.000189     -0.000237     -0.000051
# Voltality_500_log                   0.001116     -0.001423     -0.000566
# Voltality_log                      -0.061989      0.143954     -0.058018
# Sector_dum_0                        1.000000     -0.045820     -0.013376
# Sector_dum_1                       -0.045820      1.000000     -0.037407
# Sector_dum_2                       -0.013376     -0.037407      1.000000
# Sector_dum_3                       -0.057550     -0.024614     -0.095555
#
#                                 Sector_dum_3
# Prev_Close(in 10^5)                -0.086434
# High_1d(in 10^5)                   -0.086428
# Low_1d(in 10^5)                    -0.086423
# Last_1d(in 10^5)                   -0.086445
# Close                              -0.086471
# VWAP_1d(in 10^5)                   -0.086441
# Volume_1d(in 10^9)                 -0.046699
# Turnover_1d(in 10^11)              -0.140840
# Trades_1d(in 10^7)                 -0.128477
# Deliverable_Volume_1d(in 10^9)      0.001777
# pct_Deliverble_1d                   0.109229
# Open_nifty_1d(in 10^5)              0.005121
# High_nifty_1d(in 10^5)              0.005126
# Low_nifty_1d(in 10^5)               0.005114
# Close_nifty_1d(in 10^5)             0.005115
# Volume_nifty_1d(in 10^9)            0.001702
# Turnover_nifty_1d(in 10^11)         0.002613
# Open_auto_1d(in 10^5)               0.005088
# High_auto_1d(in 10^5)               0.005096
# Low_auto_1d(in 10^5)                0.005083
# Close_auto_1d(in 10^5)              0.005089
# Open_bank_1d(in 10^5)               0.004476
# High_bank_1d(in 10^5)               0.004482
# Low_bank_1d(in 10^5)                0.004464
# Close_bank_1d(in 10^5)              0.004468
# Open_fmcg_1d(in 10^5)               0.005886
# High_fmcg_1d(in 10^5)               0.005891
# Low_fmcg_1d(in 10^5)                0.005870
# Close_fmcg_1d(in 10^5)              0.005879
# Open_it_1d(in 10^5)                 0.005805
# ...                                      ...
# return_2d_it_sqr                    0.000077
# return_2d_it_cube                   0.000060
# return_3d_it_sqr                    0.000038
# return_4d_it_sqr                    0.000009
# return_5d_it_sqr                    0.000004
# Voltality_media_log                -0.000326
# Voltality_pharma_log                0.002544
# return_1d_realty_sqr               -0.000093
# return_1d_realty_cube              -0.000420
# return_2d_realty_sqr               -0.000101
# return_2d_realty_cube              -0.000410
# return_3d_realty_sqr               -0.000079
# return_3d_realty_cube              -0.000441
# return_4d_realty_sqr               -0.000147
# return_4d_realty_cube              -0.000473
# return_5d_realty_sqr               -0.000173
# return_5d_realty_cube              -0.000511
# Voltality_realty_log               -0.000652
# Voltality_psu_log                   0.000775
# return_1d_500_sqr                  -0.000035
# return_2d_500_sqr                  -0.000026
# return_3d_500_sqr                  -0.000081
# return_4d_500_sqr                  -0.000090
# return_5d_500_sqr                  -0.000102
# Voltality_500_log                  -0.000518
# Voltality_log                       0.028835
# Sector_dum_0                       -0.057550
# Sector_dum_1                       -0.024614
# Sector_dum_2                       -0.095555
# Sector_dum_3                        1.000000
#
# [212 rows x 212 columns]

# %%
os.chdir('../output_data/')
df.to_csv('train_v04.csv',index=False)
os.chdir('../Statistics/')

# %%
cols_remaining = variable_reduction.varclus(df.drop(['Close'],axis=1),cutoff=.7)
# Out:
# {0: ['Prev_Close(in 10^5)', 'High_1d(in 10^5)', 'Low_1d(in 10^5)', 'Last_1d(in 10^5)', 'VWAP_1d(in 10^5)', 'Open_1d(in 10^5)'], 1: ['Volume_1d(in 10^9)', 'Deliverable_Volume_1d(in 10^9)'], 2: ['Turnover_1d(in 10^11)', 'Trades_1d(in 10^7)', 'Volume_1d(in 10^9)_log', 'Turnover_1d(in 10^11)_log', 'Trades_1d(in 10^7)_log', 'Deliverable_Volume_1d(in 10^9)_log'], 3: ['pct_Deliverble_1d', 'pct_Deliverble_1d_sqr', 'pct_Deliverble_1d_cube', 'pct_Deliverble_1d_exp'], 4: ['Open_nifty_1d(in 10^5)', 'High_nifty_1d(in 10^5)', 'Low_nifty_1d(in 10^5)', 'Close_nifty_1d(in 10^5)', 'Open_auto_1d(in 10^5)', 'High_auto_1d(in 10^5)', 'Low_auto_1d(in 10^5)', 'Close_auto_1d(in 10^5)', 'Open_bank_1d(in 10^5)', 'High_bank_1d(in 10^5)', 'Low_bank_1d(in 10^5)', 'Close_bank_1d(in 10^5)', 'Open_fmcg_1d(in 10^5)', 'High_fmcg_1d(in 10^5)', 'Low_fmcg_1d(in 10^5)', 'Close_fmcg_1d(in 10^5)', 'Open_it_1d(in 10^5)', 'High_it_1d(in 10^5)', 'Low_it_1d(in 10^5)', 'Close_it_1d(in 10^5)', 'Open_media_1d(in 10^4)', 'High_media_1d(in 10^4)', 'Low_media_1d(in 10^4)', 'Close_media_1d(in 10^4)', 'Open_500_1d(in 10^5)', 'High_500_1d(in 10^5)', 'Low_500_1d(in 10^4)', 'Close_500_1d(in 10^4)', 'Open_nifty_1d(in 10^5)_log', 'High_nifty_1d(in 10^5)_log', 'Low_nifty_1d(in 10^5)_log', 'Close_nifty_1d(in 10^5)_log', 'Open_bank_1d(in 10^5)_log', 'High_bank_1d(in 10^5)_log', 'Low_bank_1d(in 10^5)_log', 'Close_bank_1d(in 10^5)_log', 'Open_fmcg_1d(in 10^5)_log', 'High_fmcg_1d(in 10^5)_log', 'Low_fmcg_1d(in 10^5)_log', 'Close_fmcg_1d(in 10^5)_log', 'Open_media_1d(in 10^4)_log', 'Low_media_1d(in 10^4)_log', 'Open_500_1d(in 10^5)_log', 'High_500_1d(in 10^5)_log', 'Low_500_1d(in 10^4)_log', 'Close_500_1d(in 10^4)_log', 'Open_pharma_1d(in 10^5)', 'High_pharma_1d(in 10^5)', 'Low_pharma_1d(in 10^5)', 'Close_pharma_1d(in 10^5)'], 5: ['Volume_nifty_1d(in 10^9)', 'Turnover_nifty_1d(in 10^11)', 'Volume_nifty_1d(in 10^9)_log', 'Turnover_nifty_1d(in 10^11)_log'], 6: ['Open_metal_1d(in 10^4)', 'High_metal_1d(in 10^4)', 'Low_metal_1d(in 10^4)', 'Close_metal_1d(in 10^4)', 'Open_realty_1d(in 10^3)', 'High_realty_1d(in 10^3)', 'Low_realty_1d(in 10^3)', 'Close_realty_1d(in 10^3)'], 7: ['Open_psu_1d(in 10^4)', 'High_psu_1d(in 10^4)', 'Low_psu_1d(in 10^4)', 'Close_psu_1d(in 10^4)'], 8: ['return_1d_nifty', 'return_1d_auto', 'return_1d_500', 'return_1d_bank', 'return_1d_psu', 'return_1d_metal', 'return_1d_realty', 'return_1d_realty_cube'], 9: ['return_2d_nifty', 'return_2d_auto', 'return_2d_500', 'return_2d_bank', 'return_2d_psu', 'return_2d_metal', 'return_2d_realty', 'return_2d_realty_cube'], 10: ['return_3d_nifty', 'return_3d_auto', 'return_3d_500', 'return_3d_bank', 'return_3d_psu', 'return_3d_metal', 'return_3d_realty', 'return_3d_realty_cube'], 11: ['return_4d_nifty', 'return_4d_auto', 'return_4d_500', 'return_4d_bank', 'return_4d_psu', 'return_4d_metal', 'return_4d_realty', 'return_4d_realty_cube'], 12: ['return_5d_nifty', 'return_5d_auto', 'return_5d_500', 'return_5d_bank', 'return_5d_psu', 'return_5d_metal', 'return_5d_realty', 'return_5d_realty_cube'], 13: ['Voltality_nifty', 'Voltality_auto', 'Voltality_500', 'Voltality_bank', 'Voltality_nifty_log', 'Voltality_bank_log', 'Voltality_500_log', 'Voltality_auto_log'], 14: ['return_1d_fmcg'], 15: ['return_2d_fmcg'], 16: ['return_3d_fmcg'], 17: ['return_4d_fmcg'], 18: ['return_5d_fmcg'], 19: ['Voltality_fmcg'], 20: ['return_1d_it'], 21: ['return_2d_it'], 22: ['return_3d_it'], 23: ['return_4d_it'], 24: ['return_5d_it'], 25: ['Voltality_it'], 26: ['return_1d_media'], 27: ['return_2d_media'], 28: ['return_3d_media'], 29: ['return_4d_media'], 30: ['return_5d_media'], 31: ['Voltality_media', 'Voltality_media_log'], 32: ['Voltality_metal'], 33: ['return_1d_pharma'], 34: ['return_2d_pharma'], 35: ['return_3d_pharma'], 36: ['return_4d_pharma'], 37: ['return_5d_pharma'], 38: ['Voltality_pharma', 'Voltality_pharma_log'], 39: ['Voltality_realty', 'Voltality_realty_log'], 40: ['Voltality_psu', 'Voltality_psu_log'], 41: ['return_1d'], 42: ['return_2d'], 43: ['return ...
# [('Prev_Close(in 10^5)', 1.4137595510237306e-05), ('High_1d(in 10^5)', 5.2886640326657584e-05), ('Low_1d(in 10^5)', 6.345984161699654e-05), ('Last_1d(in 10^5)', 1.855956861484946e-05), ('VWAP_1d(in 10^5)', 1.922576700284543e-05), ('Open_1d(in 10^5)', 0.00013969134789736605)]
# [('Volume_1d(in 10^9)', 0.5532622444081429), ('Deliverable_Volume_1d(in 10^9)', 0.539808684643775)]
# [('Turnover_1d(in 10^11)', 0.7204420722916813), ('Trades_1d(in 10^7)', 0.30042717024702476), ('Volume_1d(in 10^9)_log', 0.08150614742913506), ('Turnover_1d(in 10^11)_log', 0.18009888564906001), ('Trades_1d(in 10^7)_log', 0.10196197449322683), ('Deliverable_Volume_1d(in 10^9)_log', 0.08951521828727081)]
# [('pct_Deliverble_1d', 0.0032779275875911007), ('pct_Deliverble_1d_sqr', 0.00037480793717110917), ('pct_Deliverble_1d_cube', 0.002382507720568562), ('pct_Deliverble_1d_exp', 0.0005170159341916693)]
# [('Open_nifty_1d(in 10^5)', 7.486370085244172e-06), ('High_nifty_1d(in 10^5)', 5.448042115059031e-06), ('Low_nifty_1d(in 10^5)', 7.4533867339980095e-06), ('Close_nifty_1d(in 10^5)', 7.160055582747188e-06), ('Open_auto_1d(in 10^5)', 0.00016681831644943372), ('High_auto_1d(in 10^5)', 0.00011042183499659486), ('Low_auto_1d(in 10^5)', 0.00012619736011734598), ('Close_auto_1d(in 10^5)', 0.00011457886665271121), ('Open_bank_1d(in 10^5)', 2.7833108585963232e-05), ('High_bank_1d(in 10^5)', 1.9506625123783673e-05), ('Low_bank_1d(in 10^5)', 2.331363060746443e-05), ('Close_bank_1d(in 10^5)', 2.119734404625936e-05), ('Open_fmcg_1d(in 10^5)', 6.105481111134297e-05), ('High_fmcg_1d(in 10^5)', 4.008230078910196e-05), ('Low_fmcg_1d(in 10^5)', 5.186227420275309e-05), ('Close_fmcg_1d(in 10^5)', 3.891362553194782e-05), ('Open_it_1d(in 10^5)', 0.00044578015214883374), ('High_it_1d(in 10^5)', 0.0003364281531286141), ('Low_it_1d(in 10^5)', 0.0003127310427058763), ('Close_it_1d(in 10^5)', 0.00029742120147591426), ('Open_media_1d(in 10^4)', 9.281121716637324e-05), ('High_media_1d(in 10^4)', 0.0003752077185105935), ('Low_media_1d(in 10^4)', 9.266499960433407e-05), ('Close_media_1d(in 10^4)', 0.0003999916484751596), ('Open_500_1d(in 10^5)', 5.53305770571859e-06), ('High_500_1d(in 10^5)', 3.8783715727542776e-06), ('Low_500_1d(in 10^4)', 5.6697669947272665e-06), ('Close_500_1d(in 10^4)', 5.14026093225486e-06), ('Open_nifty_1d(in 10^5)_log', 8.88090597947214e-06), ('High_nifty_1d(in 10^5)_log', 5.6842390182085315e-06), ('Low_nifty_1d(in 10^5)_log', 1.2700082015992954e-05), ('Close_nifty_1d(in 10^5)_log', 9.011349356896977e-06), ('Open_bank_1d(in 10^5)_log', 2.95792122877012e-05), ('High_bank_1d(in 10^5)_log', 1.950739631727208e-05), ('Low_bank_1d(in 10^5)_log', 2.39634867127423e-05), ('Close_bank_1d(in 10^5)_log', 2.091701154138582e-05), ('Open_fmcg_1d(in 10^5)_log', 5.309808328965382e-05), ('High_fmcg_1d(in 10^5)_log', 3.1189976630499585e-05), ('Low_fmcg_1d(in 10^5)_log', 4.966099934032391e-05), ('Close_fmcg_1d(in 10^5)_log', 3.206719037867001e-05), ('Open_media_1d(in 10^4)_log', 8.743595917596643e-05), ('Low_media_1d(in 10^4)_log', 8.574717547967521e-05), ('Open_500_1d(in 10^5)_log', 5.870276476674853e-06), ('High_500_1d(in 10^5)_log', 3.884761842182291e-06), ('Low_500_1d(in 10^4)_log', 7.725403220920621e-06), ('Close_500_1d(in 10^4)_log', 6.021481542687046e-06), ('Open_pharma_1d(in 10^5)', 0.00033675216556043976), ('High_pharma_1d(in 10^5)', 0.00021642800033236527), ('Low_pharma_1d(in 10^5)', 0.0002677912743284339), ('Close_pharma_1d(in 10^5)', 0.0002302078067861878)]
# [('Volume_nifty_1d(in 10^9)', 0.04800421315681252), ('Turnover_nifty_1d(in 10^11)', 0.11170721928297887), ('Volume_nifty_1d(in 10^9)_log', 0.04317094732800286), ('Turnover_nifty_1d(in 10^11)_log', 0.09973214064881564)]
# [('Open_metal_1d(in 10^4)', 0.01070975638361073), ('High_metal_1d(in 10^4)', 0.006764045641988395), ('Low_metal_1d(in 10^4)', 0.009869152141387226), ('Close_metal_1d(in 10^4)', 0.008437330721934897), ('Open_realty_1d(in 10^3)', 0.008133660174701489), ('High_realty_1d(in 10^3)', 0.00578292770176499), ('Low_realty_1d(in 10^3)', 0.006770406913313825), ('Close_realty_1d(in 10^3)', 0.006060851978016314)]
# [('Open_psu_1d(in 10^4)', 0.0028693906221506195), ('High_psu_1d(in 10^4)', 0.002372605151720366), ('Low_psu_1d(in 10^4)', 0.002529623822393516), ('Close_psu_1d(in 10^4)', 0.002537739706678499)]
# [('return_1d_nifty', 0.05088107386888593), ('return_1d_auto', 0.48688065837040295), ('return_1d_500', 0.0433951917807048), ('return_1d_bank', 0.2303832331465629), ('return_1d_psu', 0.4237454843584463), ('return_1d_metal', 0.5772943711929881), ('return_1d_realty', 0.3626648859574678), ('return_1d_realty_cube', 0.5698988804533297)]
# [('return_2d_nifty', 0.050900752910522054), ('return_2d_auto', 0.4872111412401157), ('return_2d_500', 0.043370702027964704), ('return_2d_bank', 0.23048576150983918), ('return_2d_psu', 0.42378488060030706), ('return_2d_metal', 0.5773145526713009), ('return_2d_realty', 0.36299632535028514), ('return_2d_realty_cube', 0.5701007242743533)]
# [('return_3d_nifty', 0.05104059538188265), ('return_3d_auto', 0.4876917598910948), ('return_3d_500', 0.043426646124986534), ('return_3d_bank', 0.23080304214640046), ('return_3d_psu', 0.42420159858297557), ('return_3d_metal', 0.5776489055211428), ('return_3d_realty', 0.36326937770645146), ('return_3d_realty_cube', 0.5699773115473192)]
# [('return_4d_nifty', 0.050942776052977055), ('return_4d_auto', 0.48859463881360043), ('return_4d_500', 0.043339669998682634), ('return_4d_bank', 0.23020651379345042), ('return_4d_psu', 0.4234943596590038), ('return_4d_metal', 0.576370359582585), ('return_4d_realty', 0.36289536063782846), ('return_4d_realty_cube', 0.5695176229802634)]
# [('return_5d_nifty', 0.0509369203330329), ('return_5d_auto', 0.48977518594804054), ('return_5d_500', 0.043345049379881796), ('return_5d_bank', 0.23020790298898944), ('return_5d_psu', 0.42358411472205443), ('return_5d_metal', 0.5764284291973598), ('return_5d_realty', 0.36295555073642016), ('return_5d_realty_cube', 0.5695923627078556)]
# [('Voltality_nifty', 0.027213290969325492), ('Voltality_auto', 0.08635262630488431), ('Voltality_500', 0.031141931426159397), ('Voltality_bank', 0.07699400788825107), ('Voltality_nifty_log', 0.03202216328745113), ('Voltality_bank_log', 0.09128456815723275), ('Voltality_500_log', 0.035838770515478825), ('Voltality_auto_log', 0.09592713899044417)]
# [('Voltality_media', 0.12497108579460939), ('Voltality_media_log', 0.11738876584183193)]
# [('Voltality_pharma', 0.11275349528395802), ('Voltality_pharma_log', 0.10839032048892323)]
# [('Voltality_realty', 0.1827280738624515), ('Voltality_realty_log', 0.16498786597368942)]
# [('Voltality_psu', 0.1563053942648877), ('Voltality_psu_log', 0.151019808665323)]
# [('Voltality', 0.12063397421685126), ('Voltality_log', 0.1185679296582769)]
# [('return_1d_nifty_sqr', 0.09972688086704598), ('return_1d_500_sqr', 0.11079454861078875)]
# [('return_2d_nifty_sqr', 0.09970511403007665), ('return_2d_500_sqr', 0.11077005112139816)]
# [('return_3d_nifty_sqr', 0.0997213622313918), ('return_3d_500_sqr', 0.11079230478979568)]
# [('return_4d_nifty_sqr', 0.09962734609884086), ('return_4d_500_sqr', 0.11070293279100472)]
# [('return_5d_nifty_sqr', 0.09963226975122248), ('return_5d_500_sqr', 0.11071063988682812)]

# %%
cols_remaining
# Out:
# ['Prev_Close(in 10^5)',
#  'Deliverable_Volume_1d(in 10^9)',
#  'Volume_1d(in 10^9)_log',
#  'pct_Deliverble_1d_sqr',
#  'High_500_1d(in 10^5)',
#  'Volume_nifty_1d(in 10^9)_log',
#  'High_realty_1d(in 10^3)',
#  'High_psu_1d(in 10^4)',
#  'return_1d_500',
#  'return_2d_500',
#  'return_3d_500',
#  'return_4d_500',
#  'return_5d_500',
#  'Voltality_nifty',
#  'return_1d_fmcg',
#  'return_2d_fmcg',
#  'return_3d_fmcg',
#  'return_4d_fmcg',
#  'return_5d_fmcg',
#  'Voltality_fmcg',
#  'return_1d_it',
#  'return_2d_it',
#  'return_3d_it',
#  'return_4d_it',
#  'return_5d_it',
#  'Voltality_it',
#  'return_1d_media',
#  'return_2d_media',
#  'return_3d_media',
#  'return_4d_media',
#  'return_5d_media',
#  'Voltality_media_log',
#  'Voltality_metal',
#  'return_1d_pharma',
#  'return_2d_pharma',
#  'return_3d_pharma',
#  'return_4d_pharma',
#  'return_5d_pharma',
#  'Voltality_pharma_log',
#  'Voltality_realty_log',
#  'Voltality_psu_log',
#  'return_1d',
#  'return_2d',
#  'return_3d',
#  'return_4d',
#  'return_5d',
#  'Voltality_log',
#  'return_1d_nifty_sqr',
#  'return_1d_nifty_cube',
#  'return_2d_nifty_sqr',
#  'return_2d_nifty_cube',
#  'return_3d_nifty_sqr',
#  'return_3d_nifty_cube',
#  'return_4d_nifty_sqr',
#  'return_4d_nifty_cube',
#  'return_5d_nifty_sqr',
#  'return_5d_nifty_cube',
#  'return_1d_fmcg_sqr',
#  'return_1d_fmcg_cube',
#  'return_2d_fmcg_sqr',
#  'return_2d_fmcg_cube',
#  'return_3d_fmcg_sqr',
#  'return_3d_fmcg_cube',
#  'return_4d_fmcg_sqr',
#  'return_4d_fmcg_cube',
#  'return_5d_fmcg_sqr',
#  'return_5d_fmcg_cube',
#  'return_1d_it_sqr',
#  'return_1d_it_cube',
#  'return_2d_it_sqr',
#  'return_2d_it_cube',
#  'return_3d_it_sqr',
#  'return_4d_it_sqr',
#  'return_5d_it_sqr',
#  'return_1d_realty_sqr',
#  'return_2d_realty_sqr',
#  'return_3d_realty_sqr',
#  'return_4d_realty_sqr',
#  'return_5d_realty_sqr',
#  'Sector_dum_0',
#  'Sector_dum_1',
#  'Sector_dum_2',
#  'Sector_dum_3']

# %%
cols_dropped = set(df.columns) - set(cols_remaining+['Close'])

# %%
cols_dropped
# Out:
# {'Close_500_1d(in 10^4)',
#  'Close_500_1d(in 10^4)_log',
#  'Close_auto_1d(in 10^5)',
#  'Close_bank_1d(in 10^5)',
#  'Close_bank_1d(in 10^5)_log',
#  'Close_fmcg_1d(in 10^5)',
#  'Close_fmcg_1d(in 10^5)_log',
#  'Close_it_1d(in 10^5)',
#  'Close_media_1d(in 10^4)',
#  'Close_metal_1d(in 10^4)',
#  'Close_nifty_1d(in 10^5)',
#  'Close_nifty_1d(in 10^5)_log',
#  'Close_pharma_1d(in 10^5)',
#  'Close_psu_1d(in 10^4)',
#  'Close_realty_1d(in 10^3)',
#  'Deliverable_Volume_1d(in 10^9)_log',
#  'High_1d(in 10^5)',
#  'High_500_1d(in 10^5)_log',
#  'High_auto_1d(in 10^5)',
#  'High_bank_1d(in 10^5)',
#  'High_bank_1d(in 10^5)_log',
#  'High_fmcg_1d(in 10^5)',
#  'High_fmcg_1d(in 10^5)_log',
#  'High_it_1d(in 10^5)',
#  'High_media_1d(in 10^4)',
#  'High_metal_1d(in 10^4)',
#  'High_nifty_1d(in 10^5)',
#  'High_nifty_1d(in 10^5)_log',
#  'High_pharma_1d(in 10^5)',
#  'Last_1d(in 10^5)',
#  'Low_1d(in 10^5)',
#  'Low_500_1d(in 10^4)',
#  'Low_500_1d(in 10^4)_log',
#  'Low_auto_1d(in 10^5)',
#  'Low_bank_1d(in 10^5)',
#  'Low_bank_1d(in 10^5)_log',
#  'Low_fmcg_1d(in 10^5)',
#  'Low_fmcg_1d(in 10^5)_log',
#  'Low_it_1d(in 10^5)',
#  'Low_media_1d(in 10^4)',
#  'Low_media_1d(in 10^4)_log',
#  'Low_metal_1d(in 10^4)',
#  'Low_nifty_1d(in 10^5)',
#  'Low_nifty_1d(in 10^5)_log',
#  'Low_pharma_1d(in 10^5)',
#  'Low_psu_1d(in 10^4)',
#  'Low_realty_1d(in 10^3)',
#  'Open_1d(in 10^5)',
#  'Open_500_1d(in 10^5)',
#  'Open_500_1d(in 10^5)_log',
#  'Open_auto_1d(in 10^5)',
#  'Open_bank_1d(in 10^5)',
#  'Open_bank_1d(in 10^5)_log',
#  'Open_fmcg_1d(in 10^5)',
#  'Open_fmcg_1d(in 10^5)_log',
#  'Open_it_1d(in 10^5)',
#  'Open_media_1d(in 10^4)',
#  'Open_media_1d(in 10^4)_log',
#  'Open_metal_1d(in 10^4)',
#  'Open_nifty_1d(in 10^5)',
#  'Open_nifty_1d(in 10^5)_log',
#  'Open_pharma_1d(in 10^5)',
#  'Open_psu_1d(in 10^4)',
#  'Open_realty_1d(in 10^3)',
#  'Trades_1d(in 10^7)',
#  'Trades_1d(in 10^7)_log',
#  'Turnover_1d(in 10^11)',
#  'Turnover_1d(in 10^11)_log',
#  'Turnover_nifty_1d(in 10^11)',
#  'Turnover_nifty_1d(in 10^11)_log',
#  'VWAP_1d(in 10^5)',
#  'Voltality',
#  'Voltality_500',
#  'Voltality_500_log',
#  'Voltality_auto',
#  'Voltality_auto_log',
#  'Voltality_bank',
#  'Voltality_bank_log',
#  'Voltality_media',
#  'Voltality_nifty_log',
#  'Voltality_pharma',
#  'Voltality_psu',
#  'Voltality_realty',
#  'Volume_1d(in 10^9)',
#  'Volume_nifty_1d(in 10^9)',
#  'pct_Deliverble_1d',
#  'pct_Deliverble_1d_cube',
#  'pct_Deliverble_1d_exp',
#  'return_1d_500_sqr',
#  'return_1d_auto',
#  'return_1d_bank',
#  'return_1d_metal',
#  'return_1d_nifty',
#  'return_1d_psu',
#  'return_1d_realty',
#  'return_1d_realty_cube',
#  'return_2d_500_sqr',
#  'return_2d_auto',
#  'return_2d_bank',
#  'return_2d_metal',
#  'return_2d_nifty',
#  'return_2d_psu',
#  'return_2d_realty',
#  'return_2d_realty_cube',
#  'return_3d_500_sqr',
#  'return_3d_auto',
#  'return_3d_bank',
#  'return_3d_metal',
#  'return_3d_nifty',
#  'return_3d_psu',
#  'return_3d_realty',
#  'return_3d_realty_cube',
#  'return_4d_500_sqr',
#  'return_4d_auto',
#  'return_4d_bank',
#  'return_4d_metal',
#  'return_4d_nifty',
#  'return_4d_psu',
#  'return_4d_realty',
#  'return_4d_realty_cube',
#  'return_5d_500_sqr',
#  'return_5d_auto',
#  'return_5d_bank',
#  'return_5d_metal',
#  'return_5d_nifty',
#  'return_5d_psu',
#  'return_5d_realty',
#  'return_5d_realty_cube'}

# %%
edd_df['Status'] = ''
edd_df['Reason'] = ''

# %%
edd_df.loc[edd_df['Var'].isin(cols_dropped),'Status'] = 'drop'
edd_df.loc[edd_df['Var'].isin(cols_dropped),'Reason'] = 'Varclus'

# %%
df = df[cols_remaining+['Close']]

# %% [markdown]
# # Variance Inflation Factor

# %%
df.shape
# Out:
# (85799, 84)

# %%
cols_dropped = variable_reduction.vif_reduction(df.drop(['Close'],axis=1),limit=2.5)
# Out:
#                           features  vif factor
# 0             High_psu_1d(in 10^4)   64.854149
# 1          High_realty_1d(in 10^3)   40.902544
# 2                  Voltality_nifty   36.662500
# 3           Volume_1d(in 10^9)_log   36.003401
# 4     Volume_nifty_1d(in 10^9)_log   33.713788
# 5                   Voltality_fmcg   33.484326
# 6                     Voltality_it   29.802445
# 7             High_500_1d(in 10^5)   27.696973
# 8                  Voltality_metal   10.443706
# 9            pct_Deliverble_1d_sqr    5.214734
# 10            Voltality_realty_log    4.346310
# 11              return_2d_fmcg_sqr    3.475874
# 12                   return_3d_500    3.469292
# 13                   return_4d_500    3.463878
# 14                   return_5d_500    3.448847
# 15                   return_2d_500    3.426510
# 16                   return_1d_500    3.424219
# 17              return_1d_fmcg_sqr    3.421263
# 18              return_5d_fmcg_sqr    3.373684
# 19              return_4d_fmcg_sqr    3.291270
# 20              return_3d_fmcg_sqr    3.280738
# 21             return_1d_nifty_sqr    3.125829
# 22             return_2d_nifty_sqr    3.113692
# 23             return_3d_nifty_sqr    3.030303
# 24             return_4d_nifty_sqr    2.887280
# 25             return_5d_nifty_sqr    2.872151
# 26             return_1d_fmcg_cube    2.808847
# 27             return_2d_fmcg_cube    2.657799
# 28             return_5d_fmcg_cube    2.593288
# 29             return_4d_fmcg_cube    2.564317
# ..                             ...         ...
# 53  Deliverable_Volume_1d(in 10^9)    1.986526
# 54                    return_1d_it    1.874005
# 55                    return_2d_it    1.864947
# 56                    Sector_dum_2    1.857420
# 57            Voltality_pharma_log    1.831198
# 58               return_2d_it_cube    1.822900
# 59                    Sector_dum_1    1.820094
# 60               return_1d_it_cube    1.814902
# 61             Prev_Close(in 10^5)    1.803602
# 62                 return_5d_media    1.683820
# 63                 return_1d_media    1.683712
# 64                 return_4d_media    1.680059
# 65                 return_2d_media    1.678499
# 66                 return_3d_media    1.668462
# 67                return_4d_pharma    1.514680
# 68                return_5d_pharma    1.512350
# 69                return_1d_pharma    1.507771
# 70                return_2d_pharma    1.496929
# 71                return_3d_pharma    1.496620
# 72                   Voltality_log    1.496471
# 73             Voltality_media_log    1.364641
# 74                    Sector_dum_3    1.311298
# 75                    return_4d_it    1.263369
# 76                    return_5d_it    1.260998
# 77                    return_3d_it    1.260117
# 78                       return_1d    1.243045
# 79                       return_5d    1.242265
# 80                       return_4d    1.242056
# 81                       return_3d    1.241141
# 82                       return_2d    1.240751
#
# [83 rows x 2 columns]
# High_psu_1d(in 10^4) dropped
#                           features  vif factor
# 0                  Voltality_nifty   36.662115
# 1           Volume_1d(in 10^9)_log   35.856482
# 2                   Voltality_fmcg   33.339558
# 3          High_realty_1d(in 10^3)   31.117167
# 4                     Voltality_it   29.745877
# 5     Volume_nifty_1d(in 10^9)_log   28.230726
# 6             High_500_1d(in 10^5)   25.975123
# 7                  Voltality_metal   10.430897
# 8            pct_Deliverble_1d_sqr    5.178845
# 9             Voltality_realty_log    4.333047
# 10              return_2d_fmcg_sqr    3.473581
# 11                   return_3d_500    3.468351
# 12                   return_4d_500    3.463427
# 13                   return_5d_500    3.446626
# 14                   return_2d_500    3.425488
# 15              return_1d_fmcg_sqr    3.420344
# 16                   return_1d_500    3.419858
# 17              return_5d_fmcg_sqr    3.370236
# 18              return_4d_fmcg_sqr    3.287781
# 19              return_3d_fmcg_sqr    3.276673
# 20             return_1d_nifty_sqr    3.125826
# 21             return_2d_nifty_sqr    3.113425
# 22             return_3d_nifty_sqr    3.030062
# 23             return_4d_nifty_sqr    2.887089
# 24             return_5d_nifty_sqr    2.871864
# 25             return_1d_fmcg_cube    2.808191
# 26             return_2d_fmcg_cube    2.655158
# 27             return_5d_fmcg_cube    2.589832
# 28             return_4d_fmcg_cube    2.561823
# 29             return_3d_fmcg_cube    2.557025
# ..                             ...         ...
# 52  Deliverable_Volume_1d(in 10^9)    1.981760
# 53                    return_1d_it    1.873406
# 54                    return_2d_it    1.864770
# 55                    Sector_dum_2    1.857069
# 56            Voltality_pharma_log    1.823166
# 57               return_2d_it_cube    1.822619
# 58                    Sector_dum_1    1.819938
# 59               return_1d_it_cube    1.814775
# 60             Prev_Close(in 10^5)    1.802532
# 61                 return_1d_media    1.683035
# 62                 return_5d_media    1.681494
# 63                 return_4d_media    1.677822
# 64                 return_2d_media    1.677781
# 65                 return_3d_media    1.666575
# 66                return_4d_pharma    1.514635
# 67                return_5d_pharma    1.512149
# 68                return_1d_pharma    1.507386
# 69                return_3d_pharma    1.496608
# 70                return_2d_pharma    1.496568
# 71                   Voltality_log    1.491651
# 72             Voltality_media_log    1.364156
# 73                    Sector_dum_3    1.311153
# 74                    return_4d_it    1.261766
# 75                    return_5d_it    1.259621
# 76                    return_3d_it    1.257789
# 77                       return_1d    1.243007
# 78                       return_5d    1.242234
# 79                       return_4d    1.242042
# 80                       return_3d    1.241133
# 81                       return_2d    1.240751
#
# [82 rows x 2 columns]
# Voltality_nifty dropped
#                           features  vif factor
# 0           Volume_1d(in 10^9)_log   35.593903
# 1          High_realty_1d(in 10^3)   31.080070
# 2                     Voltality_it   29.132418
# 3     Volume_nifty_1d(in 10^9)_log   27.631805
# 4                   Voltality_fmcg   26.955592
# 5             High_500_1d(in 10^5)   25.925513
# 6                  Voltality_metal   10.235728
# 7            pct_Deliverble_1d_sqr    5.178842
# 8             Voltality_realty_log    4.203787
# 9                    return_3d_500    3.458143
# 10                   return_4d_500    3.449016
# 11                   return_5d_500    3.443728
# 12                   return_2d_500    3.413543
# 13                   return_1d_500    3.406521
# 14              return_1d_fmcg_sqr    3.130655
# 15              return_2d_fmcg_sqr    3.078879
# 16              return_5d_fmcg_sqr    3.062892
# 17              return_4d_fmcg_sqr    3.001037
# 18              return_3d_fmcg_sqr    2.970929
# 19             return_1d_fmcg_cube    2.806484
# 20             return_2d_fmcg_cube    2.653062
# 21             return_5d_fmcg_cube    2.588195
# 22             return_4d_fmcg_cube    2.559502
# 23             return_3d_fmcg_cube    2.556489
# 24                return_1d_it_sqr    2.524769
# 25                return_2d_it_sqr    2.457027
# 26                return_5d_it_sqr    2.309351
# 27                  return_1d_fmcg    2.280504
# 28                  return_2d_fmcg    2.266176
# 29                return_3d_it_sqr    2.262756
# ..                             ...         ...
# 51  Deliverable_Volume_1d(in 10^9)    1.976254
# 52                    return_1d_it    1.872389
# 53                    return_2d_it    1.862888
# 54                    Sector_dum_2    1.857069
# 55               return_2d_it_cube    1.820912
# 56                    Sector_dum_1    1.819908
# 57            Voltality_pharma_log    1.818434
# 58               return_1d_it_cube    1.814773
# 59             Prev_Close(in 10^5)    1.800302
# 60                 return_5d_media    1.681441
# 61                 return_1d_media    1.679591
# 62                 return_2d_media    1.677779
# 63                 return_4d_media    1.676123
# 64                 return_3d_media    1.666262
# 65                return_4d_pharma    1.514526
# 66                return_5d_pharma    1.511925
# 67                return_1d_pharma    1.507202
# 68                return_3d_pharma    1.496605
# 69                return_2d_pharma    1.496302
# 70                   Voltality_log    1.486377
# 71             Voltality_media_log    1.358960
# 72                    Sector_dum_3    1.311152
# 73                    return_4d_it    1.261716
# 74                    return_5d_it    1.259568
# 75                    return_3d_it    1.257751
# 76                       return_1d    1.242999
# 77                       return_5d    1.242184
# 78                       return_4d    1.242040
# 79                       return_3d    1.241107
# 80                       return_2d    1.240750
#
# [81 rows x 2 columns]
# Volume_1d(in 10^9)_log dropped
#                           features  vif factor
# 0          High_realty_1d(in 10^3)   30.462126
# 1                     Voltality_it   28.960408
# 2                   Voltality_fmcg   26.682398
# 3             High_500_1d(in 10^5)   25.691114
# 4     Volume_nifty_1d(in 10^9)_log   19.502354
# 5                  Voltality_metal   10.169096
# 6            pct_Deliverble_1d_sqr    4.987366
# 7             Voltality_realty_log    4.196180
# 8                    return_3d_500    3.458077
# 9                    return_4d_500    3.448407
# 10                   return_5d_500    3.443323
# 11                   return_2d_500    3.413487
# 12                   return_1d_500    3.406464
# 13              return_1d_fmcg_sqr    3.128524
# 14              return_2d_fmcg_sqr    3.076308
# 15              return_5d_fmcg_sqr    3.056582
# 16              return_4d_fmcg_sqr    2.995994
# 17              return_3d_fmcg_sqr    2.966397
# 18             return_1d_fmcg_cube    2.806464
# 19             return_2d_fmcg_cube    2.653061
# 20             return_5d_fmcg_cube    2.588192
# 21             return_4d_fmcg_cube    2.559500
# 22             return_3d_fmcg_cube    2.556464
# 23                return_1d_it_sqr    2.524493
# 24                return_2d_it_sqr    2.455182
# 25                return_5d_it_sqr    2.308956
# 26                  return_1d_fmcg    2.280496
# 27                  return_2d_fmcg    2.266143
# 28                return_3d_it_sqr    2.261108
# 29                  return_4d_fmcg    2.254547
# ..                             ...         ...
# 50                    return_1d_it    1.871876
# 51                    return_2d_it    1.862014
# 52               return_2d_it_cube    1.820501
# 53                    Sector_dum_1    1.818555
# 54               return_1d_it_cube    1.814301
# 55            Voltality_pharma_log    1.808226
# 56                    Sector_dum_2    1.806289
# 57                 return_5d_media    1.680926
# 58                 return_1d_media    1.679590
# 59                 return_2d_media    1.677714
# 60                 return_4d_media    1.676080
# 61                 return_3d_media    1.666162
# 62  Deliverable_Volume_1d(in 10^9)    1.586233
# 63                return_4d_pharma    1.514140
# 64                return_5d_pharma    1.511686
# 65                return_1d_pharma    1.506416
# 66                return_2d_pharma    1.496080
# 67                return_3d_pharma    1.495797
# 68                   Voltality_log    1.484552
# 69             Prev_Close(in 10^5)    1.433962
# 70             Voltality_media_log    1.358520
# 71                    Sector_dum_3    1.305849
# 72                    return_4d_it    1.261678
# 73                    return_5d_it    1.259564
# 74                    return_3d_it    1.257691
# 75                       return_1d    1.242738
# 76                       return_5d    1.241936
# 77                       return_4d    1.241754
# 78                       return_3d    1.240875
# 79                       return_2d    1.240702
#
# [80 rows x 2 columns]
# High_realty_1d(in 10^3) dropped
#                           features  vif factor
# 0                     Voltality_it   28.934965
# 1                   Voltality_fmcg   26.682343
# 2     Volume_nifty_1d(in 10^9)_log   16.569578
# 3             High_500_1d(in 10^5)   13.346253
# 4                  Voltality_metal   10.130139
# 5            pct_Deliverble_1d_sqr    4.954495
# 6             Voltality_realty_log    4.164498
# 7                    return_3d_500    3.456523
# 8                    return_4d_500    3.446951
# 9                    return_5d_500    3.443323
# 10                   return_2d_500    3.412389
# 11                   return_1d_500    3.406371
# 12              return_1d_fmcg_sqr    3.127779
# 13              return_2d_fmcg_sqr    3.074313
# 14              return_5d_fmcg_sqr    3.054768
# 15              return_4d_fmcg_sqr    2.993879
# 16              return_3d_fmcg_sqr    2.964682
# 17             return_1d_fmcg_cube    2.802488
# 18             return_2d_fmcg_cube    2.646545
# 19             return_5d_fmcg_cube    2.581077
# 20             return_4d_fmcg_cube    2.554805
# 21             return_3d_fmcg_cube    2.552859
# 22                return_1d_it_sqr    2.519816
# 23                return_2d_it_sqr    2.452113
# 24                return_5d_it_sqr    2.305545
# 25                  return_1d_fmcg    2.278364
# 26                  return_2d_fmcg    2.263453
# 27                return_3d_it_sqr    2.257461
# 28                  return_4d_fmcg    2.253362
# 29                  return_3d_fmcg    2.251033
# ..                             ...         ...
# 49                    return_1d_it    1.868282
# 50                    return_2d_it    1.858506
# 51               return_2d_it_cube    1.820402
# 52                    Sector_dum_1    1.818119
# 53               return_1d_it_cube    1.814280
# 54                    Sector_dum_2    1.806251
# 55            Voltality_pharma_log    1.773493
# 56                 return_5d_media    1.679895
# 57                 return_1d_media    1.676800
# 58                 return_2d_media    1.674536
# 59                 return_4d_media    1.673837
# 60                 return_3d_media    1.663689
# 61  Deliverable_Volume_1d(in 10^9)    1.584831
# 62                return_4d_pharma    1.513266
# 63                return_5d_pharma    1.510374
# 64                return_1d_pharma    1.505589
# 65                return_2d_pharma    1.495436
# 66                return_3d_pharma    1.495345
# 67                   Voltality_log    1.484172
# 68             Prev_Close(in 10^5)    1.433845
# 69             Voltality_media_log    1.353516
# 70                    Sector_dum_3    1.305849
# 71                    return_4d_it    1.260196
# 72                    return_5d_it    1.257002
# 73                    return_3d_it    1.255836
# 74                       return_1d    1.242738
# 75                       return_5d    1.241889
# 76                       return_4d    1.241719
# 77                       return_3d    1.240842
# 78                       return_2d    1.240688
#
# [79 rows x 2 columns]
# Voltality_it dropped
#                           features  vif factor
# 0                   Voltality_fmcg   25.950798
# 1     Volume_nifty_1d(in 10^9)_log   15.632333
# 2             High_500_1d(in 10^5)   12.567654
# 3                  Voltality_metal   10.077256
# 4            pct_Deliverble_1d_sqr    4.948604
# 5             Voltality_realty_log    4.164329
# 6                    return_3d_500    3.454613
# 7                    return_4d_500    3.446605
# 8                    return_5d_500    3.442564
# 9                    return_2d_500    3.411819
# 10                   return_1d_500    3.406227
# 11              return_1d_fmcg_sqr    3.079730
# 12              return_2d_fmcg_sqr    3.042447
# 13              return_5d_fmcg_sqr    3.013621
# 14              return_4d_fmcg_sqr    2.958288
# 15              return_3d_fmcg_sqr    2.935402
# 16             return_1d_fmcg_cube    2.801181
# 17             return_2d_fmcg_cube    2.646537
# 18             return_5d_fmcg_cube    2.580895
# 19             return_4d_fmcg_cube    2.553012
# 20             return_3d_fmcg_cube    2.552858
# 21                  return_1d_fmcg    2.278361
# 22                  return_2d_fmcg    2.262869
# 23                  return_4d_fmcg    2.253127
# 24                  return_3d_fmcg    2.249668
# 25                  return_5d_fmcg    2.249100
# 26               Voltality_psu_log    2.160809
# 27            return_5d_realty_sqr    2.095749
# 28             return_1d_nifty_sqr    2.083438
# 29             return_5d_nifty_sqr    2.083142
# ..                             ...         ...
# 48               return_2d_it_cube    1.791906
# 49            Voltality_pharma_log    1.769059
# 50                 return_5d_media    1.679852
# 51                 return_1d_media    1.676634
# 52                 return_2d_media    1.674535
# 53                 return_4d_media    1.673804
# 54                 return_3d_media    1.663681
# 55  Deliverable_Volume_1d(in 10^9)    1.584284
# 56                return_1d_it_sqr    1.539195
# 57                return_2d_it_sqr    1.527764
# 58                return_4d_pharma    1.512700
# 59                return_5d_pharma    1.509333
# 60                return_1d_pharma    1.505572
# 61                return_3d_pharma    1.494788
# 62                return_2d_pharma    1.493117
# 63                   Voltality_log    1.483045
# 64             Prev_Close(in 10^5)    1.433836
# 65                return_5d_it_sqr    1.424497
# 66                return_4d_it_sqr    1.407019
# 67                return_3d_it_sqr    1.406921
# 68             Voltality_media_log    1.353392
# 69                    Sector_dum_3    1.305832
# 70                    return_5d_it    1.255425
# 71                    return_4d_it    1.255363
# 72                    return_3d_it    1.255100
# 73                       return_1d    1.242737
# 74                       return_5d    1.241874
# 75                       return_4d    1.241697
# 76                       return_3d    1.240837
# 77                       return_2d    1.240683
#
# [78 rows x 2 columns]
# Voltality_fmcg dropped
#                           features  vif factor
# 0     Volume_nifty_1d(in 10^9)_log   13.903756
# 1             High_500_1d(in 10^5)   11.958800
# 2                  Voltality_metal    9.984181
# 3            pct_Deliverble_1d_sqr    4.930438
# 4             Voltality_realty_log    4.147600
# 5                    return_3d_500    3.454263
# 6                    return_4d_500    3.446422
# 7                    return_5d_500    3.437064
# 8                    return_2d_500    3.411809
# 9                    return_1d_500    3.405449
# 10             return_1d_fmcg_cube    2.784622
# 11             return_2d_fmcg_cube    2.607701
# 12             return_5d_fmcg_cube    2.548831
# 13             return_4d_fmcg_cube    2.531715
# 14             return_3d_fmcg_cube    2.522421
# 15                  return_1d_fmcg    2.276731
# 16                  return_2d_fmcg    2.258503
# 17                  return_4d_fmcg    2.247469
# 18                  return_5d_fmcg    2.245116
# 19                  return_3d_fmcg    2.244340
# 20               Voltality_psu_log    2.152420
# 21              return_1d_fmcg_sqr    2.144846
# 22            return_5d_realty_sqr    2.093021
# 23             return_2d_nifty_sqr    2.079980
# 24             return_1d_nifty_sqr    2.079619
# 25            return_3d_realty_sqr    2.078165
# 26             return_5d_nifty_sqr    2.071526
# 27              return_2d_fmcg_sqr    2.057650
# 28             return_4d_nifty_sqr    2.045224
# 29            return_4d_realty_sqr    2.044749
# ..                             ...         ...
# 47               return_2d_it_cube    1.790424
# 48            Voltality_pharma_log    1.764580
# 49                 return_5d_media    1.679619
# 50                 return_1d_media    1.676428
# 51                 return_2d_media    1.674487
# 52                 return_4d_media    1.673749
# 53                 return_3d_media    1.663594
# 54  Deliverable_Volume_1d(in 10^9)    1.583360
# 55                return_1d_it_sqr    1.534761
# 56                return_2d_it_sqr    1.526035
# 57                return_4d_pharma    1.512522
# 58                return_5d_pharma    1.508090
# 59                return_1d_pharma    1.505567
# 60                return_3d_pharma    1.494391
# 61                return_2d_pharma    1.491860
# 62                   Voltality_log    1.479386
# 63             Prev_Close(in 10^5)    1.433765
# 64                return_5d_it_sqr    1.423255
# 65                return_3d_it_sqr    1.406908
# 66                return_4d_it_sqr    1.406310
# 67             Voltality_media_log    1.352089
# 68                    Sector_dum_3    1.305794
# 69                    return_4d_it    1.255351
# 70                    return_5d_it    1.255191
# 71                    return_3d_it    1.253481
# 72                       return_1d    1.242730
# 73                       return_5d    1.241874
# 74                       return_4d    1.241690
# 75                       return_3d    1.240836
# 76                       return_2d    1.240682
#
# [77 rows x 2 columns]
# Volume_nifty_1d(in 10^9)_log dropped
#                           features  vif factor
# 0                  Voltality_metal    9.495920
# 1             High_500_1d(in 10^5)    8.951954
# 2            pct_Deliverble_1d_sqr    4.552908
# 3             Voltality_realty_log    4.120873
# 4                    return_4d_500    3.444491
# 5                    return_3d_500    3.444413
# 6                    return_5d_500    3.435056
# 7                    return_2d_500    3.405136
# 8                    return_1d_500    3.397522
# 9              return_1d_fmcg_cube    2.784620
# 10             return_2d_fmcg_cube    2.607090
# 11             return_5d_fmcg_cube    2.544661
# 12             return_4d_fmcg_cube    2.526966
# 13             return_3d_fmcg_cube    2.522408
# 14                  return_1d_fmcg    2.275896
# 15                  return_2d_fmcg    2.258245
# 16                  return_4d_fmcg    2.245758
# 17                  return_5d_fmcg    2.244513
# 18                  return_3d_fmcg    2.240363
# 19              return_1d_fmcg_sqr    2.144307
# 20               Voltality_psu_log    2.096664
# 21            return_5d_realty_sqr    2.086460
# 22             return_1d_nifty_sqr    2.079561
# 23             return_2d_nifty_sqr    2.079230
# 24            return_3d_realty_sqr    2.076425
# 25             return_5d_nifty_sqr    2.069683
# 26              return_2d_fmcg_sqr    2.054955
# 27            return_4d_realty_sqr    2.044524
# 28             return_4d_nifty_sqr    2.043633
# 29             return_3d_nifty_sqr    2.040721
# ..                             ...         ...
# 46               return_2d_it_cube    1.790420
# 47                 return_1d_media    1.673660
# 48                 return_5d_media    1.672817
# 49                 return_2d_media    1.671991
# 50                 return_4d_media    1.668533
# 51                 return_3d_media    1.660134
# 52  Deliverable_Volume_1d(in 10^9)    1.564310
# 53                return_1d_it_sqr    1.534001
# 54                return_2d_it_sqr    1.524948
# 55                return_4d_pharma    1.508227
# 56                return_5d_pharma    1.503325
# 57                return_1d_pharma    1.498118
# 58                return_3d_pharma    1.490283
# 59                return_2d_pharma    1.487578
# 60                   Voltality_log    1.474425
# 61            Voltality_pharma_log    1.467441
# 62             Prev_Close(in 10^5)    1.433525
# 63                return_5d_it_sqr    1.422846
# 64                return_4d_it_sqr    1.406286
# 65                return_3d_it_sqr    1.406202
# 66             Voltality_media_log    1.338786
# 67                    Sector_dum_3    1.303825
# 68                    return_4d_it    1.254729
# 69                    return_5d_it    1.254387
# 70                    return_3d_it    1.253212
# 71                       return_1d    1.242552
# 72                       return_5d    1.241872
# 73                       return_4d    1.241681
# 74                       return_3d    1.240835
# 75                       return_2d    1.240651
#
# [76 rows x 2 columns]
# Voltality_metal dropped
#                           features  vif factor
# 0             High_500_1d(in 10^5)    6.871603
# 1            pct_Deliverble_1d_sqr    4.487207
# 2             Voltality_realty_log    4.114350
# 3                    return_4d_500    3.443461
# 4                    return_3d_500    3.442776
# 5                    return_5d_500    3.434704
# 6                    return_2d_500    3.403977
# 7                    return_1d_500    3.390825
# 8              return_1d_fmcg_cube    2.782528
# 9              return_2d_fmcg_cube    2.606411
# 10             return_5d_fmcg_cube    2.544573
# 11             return_4d_fmcg_cube    2.526960
# 12             return_3d_fmcg_cube    2.522392
# 13                  return_1d_fmcg    2.275882
# 14                  return_2d_fmcg    2.257421
# 15                  return_5d_fmcg    2.243507
# 16                  return_4d_fmcg    2.242987
# 17                  return_3d_fmcg    2.234714
# 18              return_1d_fmcg_sqr    2.144295
# 19            return_5d_realty_sqr    2.065259
# 20            return_3d_realty_sqr    2.060135
# 21              return_2d_fmcg_sqr    2.054651
# 22               Voltality_psu_log    2.048639
# 23              return_3d_fmcg_sqr    2.035400
# 24             return_5d_nifty_sqr    2.035207
# 25            return_2d_realty_sqr    2.031800
# 26            return_5d_nifty_cube    2.028629
# 27             return_2d_nifty_sqr    2.028552
# 28            return_4d_realty_sqr    2.022792
# 29              return_4d_fmcg_sqr    2.022532
# ..                             ...         ...
# 45               return_2d_it_cube    1.790188
# 46                 return_1d_media    1.673077
# 47                 return_5d_media    1.672110
# 48                 return_2d_media    1.671959
# 49                 return_4d_media    1.666534
# 50                 return_3d_media    1.660108
# 51  Deliverable_Volume_1d(in 10^9)    1.563188
# 52                return_1d_it_sqr    1.529744
# 53                return_2d_it_sqr    1.523812
# 54                return_4d_pharma    1.507713
# 55                return_5d_pharma    1.502647
# 56                return_1d_pharma    1.497966
# 57                return_3d_pharma    1.489808
# 58                return_2d_pharma    1.487291
# 59            Voltality_pharma_log    1.459939
# 60                   Voltality_log    1.455848
# 61             Prev_Close(in 10^5)    1.433523
# 62                return_5d_it_sqr    1.422657
# 63                return_3d_it_sqr    1.404418
# 64                return_4d_it_sqr    1.404402
# 65             Voltality_media_log    1.332777
# 66                    Sector_dum_3    1.303680
# 67                    return_4d_it    1.254104
# 68                    return_5d_it    1.253086
# 69                    return_3d_it    1.252066
# 70                       return_1d    1.242506
# 71                       return_5d    1.241842
# 72                       return_4d    1.241665
# 73                       return_3d    1.240807
# 74                       return_2d    1.240648
#
# [75 rows x 2 columns]
# High_500_1d(in 10^5) dropped
#                           features  vif factor
# 0            pct_Deliverble_1d_sqr    4.081925
# 1             Voltality_realty_log    4.000643
# 2                    return_4d_500    3.443441
# 3                    return_3d_500    3.442505
# 4                    return_5d_500    3.433635
# 5                    return_2d_500    3.403713
# 6                    return_1d_500    3.388887
# 7              return_1d_fmcg_cube    2.772064
# 8              return_2d_fmcg_cube    2.599425
# 9              return_5d_fmcg_cube    2.528131
# 10             return_3d_fmcg_cube    2.511243
# 11             return_4d_fmcg_cube    2.510514
# 12                  return_1d_fmcg    2.274659
# 13                  return_2d_fmcg    2.255732
# 14                  return_5d_fmcg    2.240335
# 15                  return_4d_fmcg    2.236681
# 16                  return_3d_fmcg    2.230255
# 17              return_1d_fmcg_sqr    2.127203
# 18            return_3d_realty_sqr    2.043816
# 19              return_2d_fmcg_sqr    2.042381
# 20            return_5d_realty_sqr    2.037903
# 21             return_5d_nifty_sqr    2.031117
# 22            return_5d_nifty_cube    2.028546
# 23              return_3d_fmcg_sqr    2.027938
# 24             return_2d_nifty_sqr    2.025347
# 25             return_1d_nifty_sqr    2.019431
# 26            return_2d_realty_sqr    2.017256
# 27               Voltality_psu_log    2.013959
# 28            return_1d_nifty_cube    2.013006
# 29              return_4d_fmcg_sqr    2.011794
# ..                             ...         ...
# 44                 return_5d_media    1.671880
# 45                 return_1d_media    1.671560
# 46                 return_2d_media    1.671008
# 47                 return_4d_media    1.666386
# 48                 return_3d_media    1.659614
# 49                    Sector_dum_1    1.623917
# 50                return_1d_it_sqr    1.515879
# 51                return_2d_it_sqr    1.509404
# 52                return_4d_pharma    1.507711
# 53                return_5d_pharma    1.501658
# 54                return_1d_pharma    1.497890
# 55                return_3d_pharma    1.489737
# 56                return_2d_pharma    1.486579
# 57            Voltality_pharma_log    1.457627
# 58                   Voltality_log    1.454402
# 59  Deliverable_Volume_1d(in 10^9)    1.444102
# 60                return_5d_it_sqr    1.410178
# 61                return_4d_it_sqr    1.395552
# 62                return_3d_it_sqr    1.393820
# 63             Prev_Close(in 10^5)    1.325863
# 64             Voltality_media_log    1.281009
# 65                    Sector_dum_3    1.273595
# 66                    return_4d_it    1.254048
# 67                    return_5d_it    1.252426
# 68                    return_3d_it    1.252010
# 69                       return_1d    1.242295
# 70                       return_5d    1.241836
# 71                       return_4d    1.241633
# 72                       return_3d    1.240767
# 73                       return_2d    1.240547
#
# [74 rows x 2 columns]
# pct_Deliverble_1d_sqr dropped
#                           features  vif factor
# 0             Voltality_realty_log    3.991437
# 1                    return_4d_500    3.443342
# 2                    return_3d_500    3.441284
# 3                    return_5d_500    3.431274
# 4                    return_2d_500    3.402877
# 5                    return_1d_500    3.388125
# 6              return_1d_fmcg_cube    2.767822
# 7              return_2d_fmcg_cube    2.598973
# 8              return_5d_fmcg_cube    2.526289
# 9              return_3d_fmcg_cube    2.509995
# 10             return_4d_fmcg_cube    2.507877
# 11                  return_1d_fmcg    2.274352
# 12                  return_2d_fmcg    2.255712
# 13                  return_5d_fmcg    2.240115
# 14                  return_4d_fmcg    2.236114
# 15                  return_3d_fmcg    2.230240
# 16              return_1d_fmcg_sqr    2.118180
# 17              return_2d_fmcg_sqr    2.036117
# 18            return_3d_realty_sqr    2.032264
# 19             return_5d_nifty_sqr    2.030970
# 20            return_5d_nifty_cube    2.027413
# 21             return_2d_nifty_sqr    2.024971
# 22              return_3d_fmcg_sqr    2.020377
# 23            return_5d_realty_sqr    2.019028
# 24             return_1d_nifty_sqr    2.017199
# 25            return_1d_nifty_cube    2.013006
# 26               Voltality_psu_log    2.011559
# 27            return_2d_realty_sqr    2.007185
# 28            return_2d_nifty_cube    2.006894
# 29              return_4d_fmcg_sqr    2.005587
# ..                             ...         ...
# 43                 return_2d_media    1.670988
# 44                 return_5d_media    1.670890
# 45                 return_4d_media    1.666182
# 46                 return_3d_media    1.659372
# 47                    Sector_dum_1    1.595768
# 48                    Sector_dum_2    1.513844
# 49                return_1d_it_sqr    1.510930
# 50                return_4d_pharma    1.507630
# 51                return_2d_it_sqr    1.506306
# 52                return_5d_pharma    1.501657
# 53                return_1d_pharma    1.497890
# 54                return_3d_pharma    1.489653
# 55                return_2d_pharma    1.486503
# 56                return_5d_it_sqr    1.406968
# 57            Voltality_pharma_log    1.392631
# 58                return_4d_it_sqr    1.392163
# 59                return_3d_it_sqr    1.391692
# 60                   Voltality_log    1.364611
# 61  Deliverable_Volume_1d(in 10^9)    1.306848
# 62             Prev_Close(in 10^5)    1.301657
# 63             Voltality_media_log    1.271916
# 64                    return_4d_it    1.254006
# 65                    return_5d_it    1.252184
# 66                    return_3d_it    1.251772
# 67                       return_4d    1.241482
# 68                       return_5d    1.241413
# 69                       return_3d    1.240595
# 70                       return_2d    1.240507
# 71                       return_1d    1.240503
# 72                    Sector_dum_3    1.201990
#
# [73 rows x 2 columns]
# Voltality_realty_log dropped
#                           features  vif factor
# 0                    return_4d_500    3.442564
# 1                    return_3d_500    3.440934
# 2                    return_5d_500    3.431245
# 3                    return_2d_500    3.402468
# 4                    return_1d_500    3.387018
# 5              return_1d_fmcg_cube    2.765116
# 6              return_2d_fmcg_cube    2.598241
# 7              return_5d_fmcg_cube    2.521962
# 8              return_3d_fmcg_cube    2.509731
# 9              return_4d_fmcg_cube    2.503426
# 10                  return_1d_fmcg    2.273636
# 11                  return_2d_fmcg    2.255626
# 12                  return_5d_fmcg    2.239861
# 13                  return_4d_fmcg    2.235030
# 14                  return_3d_fmcg    2.229526
# 15              return_1d_fmcg_sqr    2.115696
# 16              return_2d_fmcg_sqr    2.034593
# 17             return_5d_nifty_sqr    2.030406
# 18            return_5d_nifty_cube    2.027408
# 19             return_2d_nifty_sqr    2.022999
# 20              return_3d_fmcg_sqr    2.020149
# 21             return_1d_nifty_sqr    2.017189
# 22            return_1d_nifty_cube    2.012954
# 23            return_2d_nifty_cube    2.006327
# 24              return_4d_fmcg_sqr    2.005547
# 25            return_4d_nifty_cube    2.003316
# 26               Voltality_psu_log    1.997036
# 27            return_3d_nifty_cube    1.995807
# 28             return_4d_nifty_sqr    1.989901
# 29              return_5d_fmcg_sqr    1.989898
# ..                             ...         ...
# 42                 return_2d_media    1.670984
# 43                 return_5d_media    1.670884
# 44                 return_4d_media    1.666136
# 45                 return_3d_media    1.659275
# 46                    Sector_dum_1    1.590460
# 47                return_1d_it_sqr    1.510816
# 48                    Sector_dum_2    1.509826
# 49                return_4d_pharma    1.507501
# 50                return_2d_it_sqr    1.505247
# 51                return_5d_pharma    1.501150
# 52                return_1d_pharma    1.497704
# 53                return_3d_pharma    1.488930
# 54                return_2d_pharma    1.486443
# 55                return_5d_it_sqr    1.406503
# 56                return_4d_it_sqr    1.391149
# 57                return_3d_it_sqr    1.391053
# 58            Voltality_pharma_log    1.373554
# 59                   Voltality_log    1.363989
# 60  Deliverable_Volume_1d(in 10^9)    1.297757
# 61             Prev_Close(in 10^5)    1.296888
# 62             Voltality_media_log    1.260888
# 63                    return_4d_it    1.252869
# 64                    return_5d_it    1.252158
# 65                    return_3d_it    1.249852
# 66                       return_4d    1.241481
# 67                       return_5d    1.241405
# 68                       return_3d    1.240582
# 69                       return_2d    1.240505
# 70                       return_1d    1.240500
# 71                    Sector_dum_3    1.200487
#
# [72 rows x 2 columns]
# return_4d_500 dropped
#                           features  vif factor
# 0                    return_3d_500    3.439720
# 1                    return_5d_500    3.428979
# 2                    return_2d_500    3.401894
# 3                    return_1d_500    3.387012
# 4              return_1d_fmcg_cube    2.762081
# 5              return_2d_fmcg_cube    2.592447
# 6              return_5d_fmcg_cube    2.520874
# 7              return_3d_fmcg_cube    2.509654
# 8              return_4d_fmcg_cube    2.365853
# 9                   return_1d_fmcg    2.272709
# 10                  return_2d_fmcg    2.253522
# 11                  return_5d_fmcg    2.239704
# 12                  return_3d_fmcg    2.228224
# 13              return_1d_fmcg_sqr    2.114546
# 14              return_2d_fmcg_sqr    2.033509
# 15            return_5d_nifty_cube    2.026392
# 16             return_2d_nifty_sqr    2.019341
# 17              return_3d_fmcg_sqr    2.019202
# 18             return_5d_nifty_sqr    2.016512
# 19            return_1d_nifty_cube    2.012953
# 20             return_1d_nifty_sqr    2.012090
# 21            return_2d_nifty_cube    2.005077
# 22              return_4d_fmcg_sqr    2.004916
# 23            return_3d_nifty_cube    1.995713
# 24               Voltality_psu_log    1.995681
# 25             return_4d_nifty_sqr    1.989887
# 26              return_5d_fmcg_sqr    1.988981
# 27             return_3d_nifty_sqr    1.980156
# 28                    return_1d_it    1.855359
# 29                    return_2d_it    1.849529
# ..                             ...         ...
# 41                 return_1d_media    1.670158
# 42                 return_2d_media    1.669656
# 43                 return_3d_media    1.655547
# 44                    Sector_dum_1    1.590450
# 45                    Sector_dum_2    1.509822
# 46                return_1d_it_sqr    1.509605
# 47                return_2d_it_sqr    1.505044
# 48                return_5d_pharma    1.499972
# 49                return_1d_pharma    1.497558
# 50                return_3d_pharma    1.488014
# 51                return_2d_pharma    1.486403
# 52                return_5d_it_sqr    1.406342
# 53                return_4d_it_sqr    1.390780
# 54                return_3d_it_sqr    1.389615
# 55                return_4d_pharma    1.380232
# 56            Voltality_pharma_log    1.373267
# 57                 return_4d_media    1.368390
# 58                   Voltality_log    1.363978
# 59  Deliverable_Volume_1d(in 10^9)    1.297698
# 60             Prev_Close(in 10^5)    1.296880
# 61             Voltality_media_log    1.257771
# 62                    return_5d_it    1.252048
# 63                    return_3d_it    1.248817
# 64                       return_5d    1.241401
# 65                       return_3d    1.240578
# 66                       return_2d    1.240502
# 67                       return_1d    1.240498
# 68                    Sector_dum_3    1.200484
# 69                    return_4d_it    1.178790
# 70                       return_4d    1.167850
#
# [71 rows x 2 columns]
# return_3d_500 dropped
#                           features  vif factor
# 0                    return_5d_500    3.428852
# 1                    return_2d_500    3.400497
# 2                    return_1d_500    3.386272
# 3              return_1d_fmcg_cube    2.757088
# 4              return_2d_fmcg_cube    2.592364
# 5              return_5d_fmcg_cube    2.520742
# 6              return_3d_fmcg_cube    2.372464
# 7              return_4d_fmcg_cube    2.364931
# 8                   return_1d_fmcg    2.271044
# 9                   return_2d_fmcg    2.252219
# 10                  return_5d_fmcg    2.239123
# 11              return_1d_fmcg_sqr    2.113693
# 12              return_2d_fmcg_sqr    2.032857
# 13            return_5d_nifty_cube    2.025379
# 14             return_2d_nifty_sqr    2.019225
# 15              return_3d_fmcg_sqr    2.018640
# 16             return_5d_nifty_sqr    2.014759
# 17            return_1d_nifty_cube    2.011631
# 18             return_1d_nifty_sqr    2.008143
# 19            return_2d_nifty_cube    2.004929
# 20              return_4d_fmcg_sqr    2.004355
# 21               Voltality_psu_log    1.995655
# 22              return_5d_fmcg_sqr    1.986980
# 23             return_3d_nifty_sqr    1.979787
# 24             return_4d_nifty_sqr    1.977607
# 25                    return_1d_it    1.855245
# 26                    return_2d_it    1.849150
# 27                  return_4d_fmcg    1.821055
# 28                  return_3d_fmcg    1.816546
# 29               return_1d_it_cube    1.778769
# ..                             ...         ...
# 40                 return_1d_media    1.668603
# 41                 return_2d_media    1.665646
# 42                    Sector_dum_1    1.590387
# 43                    Sector_dum_2    1.509647
# 44                return_1d_it_sqr    1.509576
# 45                return_2d_it_sqr    1.502952
# 46                return_5d_pharma    1.499563
# 47                return_1d_pharma    1.497477
# 48                return_2d_pharma    1.485216
# 49                return_5d_it_sqr    1.398978
# 50                return_4d_it_sqr    1.390670
# 51                return_3d_it_sqr    1.389038
# 52                return_4d_pharma    1.379653
# 53            Voltality_pharma_log    1.373115
# 54                 return_4d_media    1.368138
# 55                   Voltality_log    1.363971
# 56                return_3d_pharma    1.361662
# 57                 return_3d_media    1.358261
# 58  Deliverable_Volume_1d(in 10^9)    1.297694
# 59             Prev_Close(in 10^5)    1.296836
# 60             Voltality_media_log    1.255115
# 61                    return_5d_it    1.251227
# 62                       return_5d    1.241323
# 63                       return_2d    1.240499
# 64                       return_1d    1.240495
# 65                    Sector_dum_3    1.200415
# 66                    return_4d_it    1.178499
# 67                    return_3d_it    1.176673
# 68                       return_4d    1.167836
# 69                       return_3d    1.167098
#
# [70 rows x 2 columns]
# return_5d_500 dropped
#                           features  vif factor
# 0                    return_2d_500    3.400391
# 1                    return_1d_500    3.382433
# 2              return_1d_fmcg_cube    2.756924
# 3              return_2d_fmcg_cube    2.590570
# 4              return_5d_fmcg_cube    2.386968
# 5              return_3d_fmcg_cube    2.368610
# 6              return_4d_fmcg_cube    2.364675
# 7                   return_1d_fmcg    2.269177
# 8                   return_2d_fmcg    2.251409
# 9               return_1d_fmcg_sqr    2.113113
# 10              return_2d_fmcg_sqr    2.032588
# 11              return_3d_fmcg_sqr    2.016557
# 12             return_5d_nifty_sqr    2.014676
# 13             return_2d_nifty_sqr    2.014639
# 14            return_1d_nifty_cube    2.011609
# 15             return_1d_nifty_sqr    2.008140
# 16            return_2d_nifty_cube    2.004916
# 17              return_4d_fmcg_sqr    2.003375
# 18               Voltality_psu_log    1.991175
# 19              return_5d_fmcg_sqr    1.986833
# 20             return_4d_nifty_sqr    1.977381
# 21             return_3d_nifty_sqr    1.975242
# 22                    return_1d_it    1.853413
# 23                    return_2d_it    1.849135
# 24                  return_5d_fmcg    1.831927
# 25                  return_4d_fmcg    1.820355
# 26                  return_3d_fmcg    1.814594
# 27               return_1d_it_cube    1.778753
# 28                    Sector_dum_0    1.778186
# 29               return_2d_it_cube    1.774300
# ..                             ...         ...
# 39                 return_1d_media    1.660561
# 40                    Sector_dum_1    1.590297
# 41                    Sector_dum_2    1.509412
# 42                return_1d_it_sqr    1.508287
# 43                return_2d_it_sqr    1.501603
# 44                return_1d_pharma    1.496964
# 45                return_2d_pharma    1.485162
# 46                return_5d_it_sqr    1.398620
# 47                return_4d_it_sqr    1.388882
# 48                return_3d_it_sqr    1.388862
# 49                return_4d_pharma    1.379444
# 50                 return_5d_media    1.374900
# 51                return_5d_pharma    1.374104
# 52            Voltality_pharma_log    1.371120
# 53                   Voltality_log    1.363946
# 54                 return_4d_media    1.363379
# 55                return_3d_pharma    1.361652
# 56                 return_3d_media    1.357423
# 57  Deliverable_Volume_1d(in 10^9)    1.297649
# 58             Prev_Close(in 10^5)    1.296726
# 59             Voltality_media_log    1.252224
# 60                       return_2d    1.240494
# 61                       return_1d    1.240494
# 62                    Sector_dum_3    1.200334
# 63                    return_5d_it    1.178888
# 64                    return_4d_it    1.176925
# 65                    return_3d_it    1.175100
# 66                       return_4d    1.167762
# 67                       return_5d    1.167472
# 68                       return_3d    1.167096
#
# [69 rows x 2 columns]
# return_2d_500 dropped
#                           features  vif factor
# 0                    return_1d_500    3.381355
# 1              return_1d_fmcg_cube    2.756588
# 2              return_2d_fmcg_cube    2.471210
# 3              return_5d_fmcg_cube    2.386905
# 4              return_3d_fmcg_cube    2.366810
# 5              return_4d_fmcg_cube    2.364529
# 6                   return_1d_fmcg    2.267783
# 7               return_1d_fmcg_sqr    2.113021
# 8               return_2d_fmcg_sqr    2.031943
# 9               return_3d_fmcg_sqr    2.016236
# 10             return_5d_nifty_sqr    2.014518
# 11             return_2d_nifty_sqr    2.014505
# 12            return_1d_nifty_cube    2.011579
# 13             return_1d_nifty_sqr    2.008125
# 14              return_4d_fmcg_sqr    2.001590
# 15               Voltality_psu_log    1.991154
# 16              return_5d_fmcg_sqr    1.986831
# 17             return_4d_nifty_sqr    1.975767
# 18             return_3d_nifty_sqr    1.965596
# 19                  return_2d_fmcg    1.860821
# 20                    return_1d_it    1.853297
# 21                  return_5d_fmcg    1.831927
# 22                  return_4d_fmcg    1.819479
# 23                  return_3d_fmcg    1.814249
# 24                    Sector_dum_0    1.778138
# 25               return_1d_it_cube    1.778045
# 26            return_2d_nifty_cube    1.775354
# 27               return_2d_it_cube    1.767659
# 28            return_5d_nifty_cube    1.766877
# 29            return_3d_nifty_cube    1.750818
# ..                             ...         ...
# 38                    Sector_dum_1    1.590239
# 39                    Sector_dum_2    1.509242
# 40                return_1d_it_sqr    1.506101
# 41                return_2d_it_sqr    1.499293
# 42                return_1d_pharma    1.496050
# 43                return_5d_it_sqr    1.398124
# 44                return_3d_it_sqr    1.388643
# 45                return_4d_it_sqr    1.383081
# 46                return_4d_pharma    1.378941
# 47                return_5d_pharma    1.374080
# 48                 return_5d_media    1.372184
# 49            Voltality_pharma_log    1.369662
# 50                 return_2d_media    1.365550
# 51                   Voltality_log    1.363944
# 52                 return_4d_media    1.362036
# 53                return_3d_pharma    1.361409
# 54                return_2d_pharma    1.359624
# 55                 return_3d_media    1.357171
# 56  Deliverable_Volume_1d(in 10^9)    1.297649
# 57             Prev_Close(in 10^5)    1.296684
# 58             Voltality_media_log    1.249164
# 59                       return_1d    1.240489
# 60                    Sector_dum_3    1.200268
# 61                    return_5d_it    1.178833
# 62                    return_4d_it    1.175554
# 63                    return_3d_it    1.174958
# 64                       return_4d    1.167726
# 65                       return_5d    1.167456
# 66                       return_3d    1.167078
# 67                       return_2d    1.166577
#
# [68 rows x 2 columns]
# return_1d_500 dropped
#                           features  vif factor
# 0              return_1d_fmcg_cube    2.635051
# 1              return_2d_fmcg_cube    2.469465
# 2              return_5d_fmcg_cube    2.386903
# 3              return_3d_fmcg_cube    2.366775
# 4              return_4d_fmcg_cube    2.364499
# 5               return_1d_fmcg_sqr    2.112322
# 6               return_2d_fmcg_sqr    2.031714
# 7               return_3d_fmcg_sqr    2.014623
# 8              return_5d_nifty_sqr    2.013482
# 9              return_1d_nifty_sqr    2.007838
# 10             return_2d_nifty_sqr    2.004776
# 11              return_4d_fmcg_sqr    2.001572
# 12               Voltality_psu_log    1.990455
# 13              return_5d_fmcg_sqr    1.986815
# 14             return_4d_nifty_sqr    1.975709
# 15             return_3d_nifty_sqr    1.963672
# 16                  return_1d_fmcg    1.878581
# 17                  return_2d_fmcg    1.860245
# 18                  return_5d_fmcg    1.831720
# 19                  return_4d_fmcg    1.819451
# 20                  return_3d_fmcg    1.813720
# 21            return_1d_nifty_cube    1.781024
# 22                    Sector_dum_0    1.778108
# 23            return_2d_nifty_cube    1.775068
# 24               return_1d_it_cube    1.770897
# 25               return_2d_it_cube    1.767636
# 26            return_5d_nifty_cube    1.765897
# 27                    return_1d_it    1.754787
# 28                    return_2d_it    1.749659
# 29            return_3d_nifty_cube    1.749112
# ..                             ...         ...
# 37                    Sector_dum_2    1.509095
# 38                return_1d_it_sqr    1.503945
# 39                return_2d_it_sqr    1.498986
# 40                return_5d_it_sqr    1.397805
# 41                return_3d_it_sqr    1.383363
# 42                return_4d_it_sqr    1.382373
# 43                return_4d_pharma    1.378868
# 44                return_5d_pharma    1.373696
# 45                 return_5d_media    1.372034
# 46                return_1d_pharma    1.370514
# 47            Voltality_pharma_log    1.367425
# 48                 return_2d_media    1.365402
# 49                 return_1d_media    1.364502
# 50                   Voltality_log    1.363944
# 51                return_3d_pharma    1.360802
# 52                 return_4d_media    1.359802
# 53                return_2d_pharma    1.359375
# 54                 return_3d_media    1.356099
# 55  Deliverable_Volume_1d(in 10^9)    1.297645
# 56             Prev_Close(in 10^5)    1.296628
# 57             Voltality_media_log    1.247743
# 58                    Sector_dum_3    1.200211
# 59                    return_5d_it    1.178567
# 60                    return_4d_it    1.175543
# 61                    return_3d_it    1.173585
# 62                       return_4d    1.167722
# 63                       return_5d    1.167292
# 64                       return_3d    1.167046
# 65                       return_2d    1.166561
# 66                       return_1d    1.166147
#
# [67 rows x 2 columns]
# return_1d_fmcg_cube dropped
#                           features  vif factor
# 0              return_2d_fmcg_cube    2.469072
# 1              return_3d_fmcg_cube    2.366191
# 2              return_5d_fmcg_cube    2.364779
# 3              return_4d_fmcg_cube    2.363068
# 4               return_2d_fmcg_sqr    2.031392
# 5               return_3d_fmcg_sqr    2.013960
# 6              return_1d_nifty_sqr    2.005619
# 7              return_2d_nifty_sqr    2.003994
# 8               return_4d_fmcg_sqr    2.000020
# 9                Voltality_psu_log    1.989905
# 10             return_5d_nifty_sqr    1.986789
# 11              return_5d_fmcg_sqr    1.982503
# 12             return_4d_nifty_sqr    1.975557
# 13             return_3d_nifty_sqr    1.963576
# 14                  return_2d_fmcg    1.857685
# 15                  return_5d_fmcg    1.826334
# 16                  return_4d_fmcg    1.817781
# 17                  return_3d_fmcg    1.813639
# 18                    Sector_dum_0    1.777230
# 19              return_1d_fmcg_sqr    1.773163
# 20            return_2d_nifty_cube    1.771098
# 21               return_2d_it_cube    1.767223
# 22            return_5d_nifty_cube    1.751204
# 23                    return_2d_it    1.748991
# 24            return_3d_nifty_cube    1.748260
# 25            return_4d_nifty_cube    1.746925
# 26                    return_1d_it    1.740071
# 27               return_1d_it_cube    1.710815
# 28            return_3d_realty_sqr    1.694933
# 29            return_2d_realty_sqr    1.682929
# ..                             ...         ...
# 36                return_2d_it_sqr    1.498975
# 37            return_1d_nifty_cube    1.446227
# 38                return_5d_it_sqr    1.386785
# 39                return_3d_it_sqr    1.383246
# 40                return_4d_it_sqr    1.381582
# 41                return_4d_pharma    1.375430
# 42                return_5d_pharma    1.373655
# 43                 return_5d_media    1.371831
# 44            Voltality_pharma_log    1.365039
# 45                   Voltality_log    1.363940
# 46                 return_2d_media    1.363492
# 47                return_3d_pharma    1.360714
# 48                return_1d_pharma    1.359940
# 49                return_2d_pharma    1.358263
# 50                 return_3d_media    1.356096
# 51                 return_4d_media    1.354003
# 52                 return_1d_media    1.352175
# 53                  return_1d_fmcg    1.322728
# 54  Deliverable_Volume_1d(in 10^9)    1.296441
# 55             Prev_Close(in 10^5)    1.295860
# 56             Voltality_media_log    1.246483
# 57                    Sector_dum_3    1.199816
# 58                    return_5d_it    1.178552
# 59                    return_4d_it    1.175428
# 60                    return_3d_it    1.173412
# 61                       return_4d    1.167713
# 62                       return_5d    1.167272
# 63                       return_3d    1.166873
# 64                       return_2d    1.166547
# 65                       return_1d    1.162814
#
# [66 rows x 2 columns]

# %%
cols_dropped = [x for x in cols_dropped if 'dum' not in x]

# %%
cols_dropped
# Out:
# ['High_psu_1d(in 10^4)',
#  'Voltality_nifty',
#  'Volume_1d(in 10^9)_log',
#  'High_realty_1d(in 10^3)',
#  'Voltality_it',
#  'Voltality_fmcg',
#  'Volume_nifty_1d(in 10^9)_log',
#  'Voltality_metal',
#  'High_500_1d(in 10^5)',
#  'pct_Deliverble_1d_sqr',
#  'Voltality_realty_log',
#  'return_4d_500',
#  'return_3d_500',
#  'return_5d_500',
#  'return_2d_500',
#  'return_1d_500',
#  'return_1d_fmcg_cube']

# %%
edd_df.loc[edd_df['Var'].isin(cols_dropped),'Status'] = 'drop'
edd_df.loc[edd_df['Var'].isin(cols_dropped),'Reason'] = 'VIF'

# %%
df.drop(cols_dropped,axis=1,inplace=True)

# %% [markdown]
# # BackWard Selection

# %%
cols_dropped = variable_reduction.backward_selection(df,dv='Close',alpha=.05)
# Out:
# Voltality_psu_log-0.874757097316486
# return_1d_it_sqr-0.8396785577718718
# return_2d_fmcg-0.8354535319552056
# return_3d_fmcg_sqr-0.831738977449356
# return_3d_realty_sqr-0.7805226421623743
# return_2d_pharma-0.7764134765249369
# Voltality_media_log-0.7476312114092786
# return_4d_media-0.7520466746653186
# return_2d_fmcg_sqr-0.7366210238968789
# Sector_dum_0-0.666414283358164
# return_4d_fmcg-0.6003450955852924
# return_4d_pharma-0.46504552847613134
# return_5d_pharma-0.4751275085842219
# return_5d_it_sqr-0.46085415736250934
# Sector_dum_1-0.4812076468877269
# Voltality_pharma_log-0.48874594835550533
# return_5d_media-0.43503219311558317
# Sector_dum_2-0.42929631770226073
# Sector_dum_3-0.40145713754110635
# return_2d-0.39723647925692285
# return_4d_nifty_cube-0.38639916261904794
# return_5d_fmcg_sqr-0.30035765153627425
# return_4d_fmcg_sqr-0.2974807578867652
# return_3d_pharma-0.27864610662586736
# return_3d_it-0.3425185775751852
# return_1d_nifty_cube-0.2715993554231313
# return_1d_fmcg-0.3046411609474777
# Voltality_log-0.22832400857989343
# return_3d_fmcg-0.231668574818992
# return_3d_fmcg_cube-0.3283102181560925
# return_3d_media-0.24592279370363224
# return_5d_realty_sqr-0.24665714885191986
# return_2d_fmcg_cube-0.231503156807227
# return_1d_fmcg_sqr-0.20692379550922602
# return_1d_pharma-0.22807571928232906
# return_5d-0.1978279409129106
# return_4d_fmcg_cube-0.15162220580807417
# return_3d-0.12590912615656874
# return_5d_nifty_sqr-0.12740684249635972
# return_4d_realty_sqr-0.13486814888635193
# return_1d_it_cube-0.1219282132063331
# return_4d_it-0.12028253695469902
# Deliverable_Volume_1d(in 10^9)-0.10355470375435498
# return_4d_nifty_sqr-0.11281434296812981
# return_2d_nifty_sqr-0.09041228621380304
# return_2d_it_cube-0.11990386430844718
# return_2d_it-0.2591880621864658
# return_2d_it_sqr-0.1499286903590152
# return_5d_nifty_cube-0.0596170092654986
# return_1d_it-0.052567797374773906
# return_2d_realty_sqr-0.022721561053116977

# %%
cols_dropped
# Out:
# ['Voltality_psu_log',
#  'return_1d_it_sqr',
#  'return_2d_fmcg',
#  'return_3d_fmcg_sqr',
#  'return_3d_realty_sqr',
#  'return_2d_pharma',
#  'Voltality_media_log',
#  'return_4d_media',
#  'return_2d_fmcg_sqr',
#  'Sector_dum_0',
#  'return_4d_fmcg',
#  'return_4d_pharma',
#  'return_5d_pharma',
#  'return_5d_it_sqr',
#  'Sector_dum_1',
#  'Voltality_pharma_log',
#  'return_5d_media',
#  'Sector_dum_2',
#  'Sector_dum_3',
#  'return_2d',
#  'return_4d_nifty_cube',
#  'return_5d_fmcg_sqr',
#  'return_4d_fmcg_sqr',
#  'return_3d_pharma',
#  'return_3d_it',
#  'return_1d_nifty_cube',
#  'return_1d_fmcg',
#  'Voltality_log',
#  'return_3d_fmcg',
#  'return_3d_fmcg_cube',
#  'return_3d_media',
#  'return_5d_realty_sqr',
#  'return_2d_fmcg_cube',
#  'return_1d_fmcg_sqr',
#  'return_1d_pharma',
#  'return_5d',
#  'return_4d_fmcg_cube',
#  'return_3d',
#  'return_5d_nifty_sqr',
#  'return_4d_realty_sqr',
#  'return_1d_it_cube',
#  'return_4d_it',
#  'Deliverable_Volume_1d(in 10^9)',
#  'return_4d_nifty_sqr',
#  'return_2d_nifty_sqr',
#  'return_2d_it_cube',
#  'return_2d_it',
#  'return_2d_it_sqr',
#  'return_5d_nifty_cube',
#  'return_1d_it']

# %%
edd_df.loc[edd_df['Var'].isin(cols_dropped),'Status'] = 'drop'
edd_df.loc[edd_df['Var'].isin(cols_dropped),'Reason'] = 'Backward Selection'

# %%
df.drop(cols_dropped,axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Prev_Close(in 10^5)', 'return_5d_fmcg', 'return_5d_it',
#        'return_1d_media', 'return_2d_media', 'return_1d', 'return_4d',
#        'return_1d_nifty_sqr', 'return_2d_nifty_cube', 'return_3d_nifty_sqr',
#        'return_3d_nifty_cube', 'return_5d_fmcg_cube', 'return_3d_it_sqr',
#        'return_4d_it_sqr', 'return_1d_realty_sqr', 'return_2d_realty_sqr',
#        'Close'],
#       dtype='object')

# %%
os.chdir('../Statistics/')
book = load_workbook('report.xlsx')
writer = pd.ExcelWriter('report.xlsx', engine='openpyxl') 
writer.book = book
writer.sheets = dict((ws.title, ws) for ws in book.worksheets)

edd_df.to_excel(writer, "edd_v04", index=False)

writer.save()

# %%
os.chdir('../output_data')

# %%
df.to_csv('train_lr.csv',index=False)

# %%
df.shape
# Out:
# (85799, 17)
